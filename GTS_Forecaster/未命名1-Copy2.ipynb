# %% [markdown]
# # GNSS时间序列预测深度学习模型

# %% [markdown]
# ### 本Notebook实现基于深度学习的GNSS时间序列预测，支持LSTM/GRU/TCN/Transformer等模型
# ## 1. 环境准备

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import time
import math
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import plotly.express as px
import plotly.graph_objects as go
from utils import split_data
import argparse
import os
from model import *
from utils import *
from pathlib import Path

plt.rcParams['font.family'] = ['SimHei']  # 替换为你的字体名称
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False  # 解决负号显示问题

# %% [markdown]
# # 解析命令行参数

# %%
parser = argparse.ArgumentParser()
# data
parser.add_argument('--path', type=str, default='../data/9output.csv', help="文件路径")
parser.add_argument('--vision', type=bool, default=True)
parser.add_argument('--input_features', type=list, default=['time','value'], help="输入特征")
parser.add_argument('--output_features', type=list, default=['value'], help="输出特征")
parser.add_argument('--window_size', type=int, default=500)
parser.add_argument('--train_test_ratio', type=float, default=0.3)
parser.add_argument('--random_state', type=int, default=34)
# model
parser.add_argument('--model_name', type=str, default='TCN_ekan', help='模型名称选项，LSTM,LSTM_ekan,TCN_ekan,TCN,Transformer,Transformer_ekan,BiLSTM,BiLSTM_ekan,GRU,GRU_ekan,LSTM_Attention，VanillaLSTM，ConvLSTM，CustomLSTM')
parser.add_argument('--dropout', type=float, default=0.1)
parser.add_argument('--hidden_dim', type=int, default=32)
parser.add_argument('--n_layers', type=int, default=2)
##kan
parser.add_argument('--grid_size', type=int, default=200, help='grid')
##TCN
parser.add_argument('--num_channels', type=list, default=[25, 50, 25])
parser.add_argument('--kernel_size', type=int, default=3)
##transformer
parser.add_argument('--num_heads', type=int, default=8)  # 确保这行存在
parser.add_argument('--hidden_space', type=int, default=32)
# training
parser.add_argument('--num_epochs', type=int, default=10000)
parser.add_argument('--seed', type=int, default=1)
# optimizer
parser.add_argument('--lr', type=float, default=0.001, help='学习率')
# 在参数解析部分添加TimeGNN专用参数
#parser.add_argument('--seq_len', type=int, default=24, help='时间序列长度')
parser.add_argument('--aggregate', type=str, default='last', choices=['mean', 'last'])
parser.add_argument('--keep_self_loops', action='store_true')
parser.add_argument('--enforce_consecutive', action='store_true')
parser.add_argument('--block_size', type=int, default=3)
parser.add_argument('--batch_size', type=int, default=32)  # 新增关键行
parser.add_argument('--seq_len', type=int, default=24)      # TimeGNN专用参数

parser.add_argument('--predict_start', type=int, default=1000, help='Start index in original data for prediction')
parser.add_argument('--predict_end', type=int, default=1655, help='End index in original data for prediction')

# 早停参数
parser.add_argument('--use_early_stopping', action='store_true', help='启用早停')
parser.add_argument('--patience', type=int, default=250, help='早停耐心值')
parser.add_argument('--delta', type=float, default=0, help='早停最小变化量')
# 预测数量参数
parser.add_argument('--predict_nums', type=int, nargs='+', default=[30, 60, 360], help='预测长度列表，即为预测天数')
#args = parser.parse_args(args=[''])
args = parser.parse_args(args=['--use_early_stopping'])
args.device = torch.device('cpu')

# %% [markdown]
# ## 读取数据

# %%
data = pd.read_csv(args.path)
# 按照时间排序
data = data.sort_values('time')

# %% [markdown]
# # 数据可视化

# %%
if args.vision:
    sns.set_style("darkgrid")
    plt.figure(figsize=(15, 9))
    plt.plot(data['value'], label='value')
    plt.xticks(range(0, data.shape[0], 20), data['time'].iloc[::20], rotation=45)
    plt.title("GNSS Time Series", fontsize=18, fontweight='bold')
    plt.xlabel('value', fontsize=18)
    plt.ylabel('GNSS Value', fontsize=18)
    plt.legend()

# %% [markdown]
# # 特征缩放
# 缩放为计算机可以看懂的语言

# %%
features = data[args.input_features]
scaler = MinMaxScaler(feature_range=(-1, 1))
features_scaled = scaler.fit_transform(features)

target = data[args.output_features]
target_scaler = MinMaxScaler(feature_range=(-1, 1))
target_scaled = target_scaler.fit_transform(target)

one_scaler = MinMaxScaler(feature_range=(-1, 1))
one_scaled = one_scaler.fit_transform(data[['value']])

output_colnames = args.output_features
param = list(output_colnames)
param_index = range(len(param))
param_index_dict = dict(zip(param_index, param))

# %% [markdown]
# # 数据拆分

# %%
x_train, y_train, x_test, y_test = split_data(features_scaled, target_scaled, args.window_size)
print('x_train.shape = ', x_train.shape)
print('y_train.shape = ', y_train.shape)
print('x_test.shape = ', x_test.shape)
print('y_test.shape = ', y_test.shape)
# Out:
# x_train.shape =  (1270, 499, 2)
# y_train.shape =  (1270, 1)
# x_test.shape =  (318, 499, 2)
# y_test.shape =  (318, 1)

# %% [markdown]
# # 进一步划分训练集和验证集 BEFORE 转换为 Torch 张量

# %%
x_train, x_val, y_train, y_val = train_test_split(
    x_train, y_train, test_size=args.train_test_ratio, random_state=args.random_state
)
print('x_train.shape = ', x_train.shape)
print('y_train.shape = ', y_train.shape)
print('x_val.shape = ', x_val.shape)
print('y_val.shape = ', y_val.shape)
print('x_test.shape = ', x_test.shape)
print('y_test.shape = ', y_test.shape)
# Out:
# x_train.shape =  (889, 499, 2)
# y_train.shape =  (889, 1)
# x_val.shape =  (381, 499, 2)
# y_val.shape =  (381, 1)
# x_test.shape =  (318, 499, 2)
# y_test.shape =  (318, 1)

# %% [markdown]
# # 将 NumPy 数组转换为 Torch 张量 AFTER 分割

# %%
x_train = torch.from_numpy(x_train).type(torch.Tensor).to(args.device)
x_val = torch.from_numpy(x_val).type(torch.Tensor).to(args.device)
y_train = torch.from_numpy(y_train).type(torch.Tensor).to(args.device)
y_val = torch.from_numpy(y_val).type(torch.Tensor).to(args.device)
x_test = torch.from_numpy(x_test).type(torch.Tensor).to(args.device)
y_test = torch.from_numpy(y_test).type(torch.Tensor).to(args.device)

# %% [markdown]
# # 确保数据类型正确

# %%
assert isinstance(y_train, torch.Tensor), "y_train is not a tensor"

# %% [markdown]
# # 模型初始化

# %%
if args.model_name == 'LSTM':
    model = LSTM(input_dim=len(args.input_features), hidden_dim=args.hidden_dim, num_layers=args.n_layers, output_dim=len(args.output_features))
elif args.model_name == 'LSTM_ekan':
    model = LSTM_ekan(input_dim=len(args.input_features), hidden_dim=args.hidden_dim, num_layers=args.n_layers, output_dim=len(args.output_features))
elif args.model_name == 'BiLSTM':
    model = BiLSTM(input_dim=len(args.input_features), hidden_dim=args.hidden_dim, num_layers=args.n_layers, output_dim=len(args.output_features))
elif args.model_name == 'BiLSTM_ekan':
    model = BiLSTM_ekan(input_dim=len(args.input_features), hidden_dim=args.hidden_dim, num_layers=args.n_layers, output_dim=len(args.output_features))
elif args.model_name == 'GRUwGNN':
    model = GRUwGNN(input_dim=len(args.input_features), hidden_dim=args.hidden_dim, num_layers=args.n_layers, output_dim=len(args.output_features))
elif args.model_name == 'GRU_ekanwGNN':
    model = GRU_ekanwGNN(input_dim=len(args.input_features), hidden_dim=args.hidden_dim, num_layers=args.n_layers, output_dim=len(args.output_features))
elif args.model_name == 'LSTM_Attention':
    model = LSTM_Attention(input_dim=len(args.input_features), hidden_dim=args.hidden_dim, num_layers=args.n_layers, output_dim=len(args.output_features))
elif args.model_name == 'CustomLSTM':
    model = CustomLSTM(input_dim=len(args.input_features), hidden_dim=args.hidden_dim, num_layers=args.n_layers, output_dim=len(args.output_features))
elif args.model_name == 'GRU':
    model = GRU(input_dim=len(args.input_features), hidden_dim=args.hidden_dim, num_layers=args.n_layers, output_dim=len(args.output_features))
elif args.model_name == 'ConvLSTM':
    model = ConvLSTM(
    input_dim=19,
    hidden_dim=args.hidden_dim,
    num_layers=args.n_layers,
    output_dim=len(args.output_features),
    kernel_size=args.kernel_size
)
elif args.model_name == 'TimeGNN':
    model = TimeGNN(
        # 移除loss参数
        input_dim=len(args.input_features),
        hidden_dim=args.hidden_dim,
        output_dim=len(args.output_features),
        seq_len=args.seq_len,
        batch_size=args.batch_size,
        aggregate=args.aggregate,
        keep_self_loops=args.keep_self_loops,
        enforce_consecutive=args.enforce_consecutive,
        block_size=args.block_size
    )
elif args.model_name == 'Informer':
    model = Informer(input_dim=len(args.input_features), hidden_dim=args.hidden_dim, num_layers=args.n_layers, num_heads=args.num_heads, output_dim=len(args.output_features), dropout_rate=args.dropout)
elif args.model_name == 'ConvGRU':
    model = ConvGRU(
    input_dim=len(args.input_features),
    hidden_dim=args.hidden_dim,
    num_layers=args.n_layers,
    output_dim=len(args.output_features),
    kernel_size=args.kernel_size
)
elif args.model_name == 'VanillaLSTM':
    model = VanillaLSTM(input_dim=len(args.input_features), hidden_dim=args.hidden_dim, num_layers=args.n_layers, output_dim=len(args.output_features))
elif args.model_name == 'GRU_ekan':
    model = GRU_ekan(input_dim=len(args.input_features), hidden_dim=args.hidden_dim, num_layers=args.n_layers, output_dim=len(args.output_features))
elif args.model_name == 'TCN':
    model = TemporalConvNet(num_inputs=len(args.input_features), num_outputs=len(args.output_features), num_channels=args.num_channels, kernel_size=args.kernel_size, dropout=args.dropout)
elif args.model_name == 'TCN_ekan':
    model = TemporalConvNet_ekan(num_inputs=len(args.input_features), num_outputs=len(args.output_features), num_channels=args.num_channels, kernel_size=args.kernel_size, dropout=args.dropout)
elif args.model_name == 'Transformer':
    model = TimeSeriesTransformer(input_dim=len(args.input_features), num_heads=args.num_heads, num_layers=args.n_layers, num_outputs=len(args.output_features), hidden_space=args.hidden_space, dropout_rate=args.dropout)
elif args.model_name == 'Transformer_ekan':
    model = TimeSeriesTransformer_ekan(input_dim=len(args.input_features), num_heads=args.num_heads, num_layers=args.n_layers, num_outputs=len(args.output_features), hidden_space=args.hidden_space, dropout_rate=args.dropout)
else:
    raise ValueError('请选择正确的模型名称')
model = model.to(args.device)

# %% [markdown]
# # 损失函数和优化器

# %%
criterion = nn.MSELoss()
optimiser = torch.optim.Adam(model.parameters(), lr=args.lr)

# %% [markdown]
# # 初始化 EarlyStopping（如果启用）

# %%
if args.use_early_stopping:
    checkpoint_path = f'../{args.model_name}/best_model.pt'
    early_stopping = EarlyStopping(patience=args.patience, verbose=True, delta=args.delta, path=checkpoint_path)
    print("启用早停机制。")
else:
    early_stopping = None
    print("未启用早停机制。")
# Out:
# 启用早停机制。

# %% [markdown]
# # 初始化历史记录

# %%
train_MSE_hist = []
train_R2_hist = []
train_MAE_hist = []
val_MSE_hist = []
val_R2_hist = []
val_MAE_hist = []

output_dir_train = f'../{args.model_name}/train'
output_dir_val = f'../{args.model_name}/val'
output_dir_test = f'../{args.model_name}/test'  # 明确声明

os.makedirs(output_dir_train, exist_ok=True)
os.makedirs(output_dir_val, exist_ok=True)
os.makedirs(output_dir_test, exist_ok=True)  # 创建目录

# %% [markdown]
# # 开始训练

# %%
start_time = time.time()
result = []
for epoch in range(args.num_epochs):
    # 训练模式
    model.train()
    y_train_pred = model(x_train)
    # 计算训练损失
    train_loss = criterion(y_train_pred, y_train)
    # 反向传播和优化
    optimiser.zero_grad()
    train_loss.backward()
    optimiser.step()
    # 计算训练 R2 和 MAE
    train_r2 = r2_score(y_train.detach().cpu().numpy(), y_train_pred.detach().cpu().numpy())
    train_mae = mean_absolute_error(y_train.detach().cpu().numpy(), y_train_pred.detach().cpu().numpy())
    # 验证模式
    model.eval()
    with torch.no_grad():
        y_val_pred = model(x_val)
        val_loss = criterion(y_val_pred, y_val)
        val_r2 = r2_score(y_val.detach().cpu().numpy(), y_val_pred.detach().cpu().numpy())
        val_mae = mean_absolute_error(y_val.detach().cpu().numpy(), y_val_pred.detach().cpu().numpy())
    # 打印训练和验证信息
    print(f"Epoch {epoch+1}/{args.num_epochs} | "
          f"Train MSE: {train_loss.item():.4f} | Train MAE: {train_mae:.4f} | Train R2: {train_r2:.4f} | "
          f"Val MSE: {val_loss.item():.4f} | Val MAE: {val_mae:.4f} | Val R2: {val_r2:.4f}")
    # 记录历史
    train_MSE_hist.append(train_loss.item())
    train_R2_hist.append(train_r2)
    train_MAE_hist.append(train_mae)
    val_MSE_hist.append(val_loss.item())
    val_R2_hist.append(val_r2)
    val_MAE_hist.append(val_mae)
    # 早停检查（如果启用）
    if args.use_early_stopping:
        early_stopping(val_loss.item(), model)
        if early_stopping.early_stop:
            print("早停机制触发，停止训练。")
            break
# Out:
# Epoch 1/10000 | Train MSE: 0.0810 | Train MAE: 0.2239 | Train R2: -0.4825 | Val MSE: 0.0646 | Val MAE: 0.1969 | Val R2: -0.3490
# Validation loss decreased (inf --> 0.064641).  Saving model ...
# Epoch 2/10000 | Train MSE: 0.0780 | Train MAE: 0.2190 | Train R2: -0.4265 | Val MSE: 0.0622 | Val MAE: 0.1928 | Val R2: -0.2987
# Validation loss decreased (0.064641 --> 0.062233).  Saving model ...
# Epoch 3/10000 | Train MSE: 0.0750 | Train MAE: 0.2146 | Train R2: -0.3727 | Val MSE: 0.0598 | Val MAE: 0.1886 | Val R2: -0.2487
# Validation loss decreased (0.062233 --> 0.059834).  Saving model ...
# Epoch 4/10000 | Train MSE: 0.0722 | Train MAE: 0.2099 | Train R2: -0.3211 | Val MSE: 0.0573 | Val MAE: 0.1843 | Val R2: -0.1965
# Validation loss decreased (0.059834 --> 0.057336).  Saving model ...
# Epoch 5/10000 | Train MSE: 0.0692 | Train MAE: 0.2050 | Train R2: -0.2660 | Val MSE: 0.0550 | Val MAE: 0.1801 | Val R2: -0.1468
# Validation loss decreased (0.057336 --> 0.054951).  Saving model ...
# Epoch 6/10000 | Train MSE: 0.0662 | Train MAE: 0.2004 | Train R2: -0.2119 | Val MSE: 0.0526 | Val MAE: 0.1763 | Val R2: -0.0977
# Validation loss decreased (0.054951 --> 0.052599).  Saving model ...
# Epoch 7/10000 | Train MSE: 0.0632 | Train MAE: 0.1953 | Train R2: -0.1557 | Val MSE: 0.0503 | Val MAE: 0.1727 | Val R2: -0.0489
# Validation loss decreased (0.052599 --> 0.050264).  Saving model ...
# Epoch 8/10000 | Train MSE: 0.0602 | Train MAE: 0.1909 | Train R2: -0.1018 | Val MSE: 0.0480 | Val MAE: 0.1694 | Val R2: -0.0024
# Validation loss decreased (0.050264 --> 0.048035).  Saving model ...
# Epoch 9/10000 | Train MSE: 0.0573 | Train MAE: 0.1861 | Train R2: -0.0489 | Val MSE: 0.0461 | Val MAE: 0.1670 | Val R2: 0.0388
# Validation loss decreased (0.048035 --> 0.046058).  Saving model ...
# Epoch 10/10000 | Train MSE: 0.0548 | Train MAE: 0.1820 | Train R2: -0.0018 | Val MSE: 0.0445 | Val MAE: 0.1652 | Val R2: 0.0713
# Validation loss decreased (0.046058 --> 0.044500).  Saving model ...
# Epoch 11/10000 | Train MSE: 0.0521 | Train MAE: 0.1775 | Train R2: 0.0475 | Val MSE: 0.0435 | Val MAE: 0.1647 | Val R2: 0.0921
# Validation loss decreased (0.044500 --> 0.043505).  Saving model ...
# Epoch 12/10000 | Train MSE: 0.0505 | Train MAE: 0.1750 | Train R2: 0.0764 | Val MSE: 0.0432 | Val MAE: 0.1652 | Val R2: 0.0985
# Validation loss decreased (0.043505 --> 0.043197).  Saving model ...
# Epoch 13/10000 | Train MSE: 0.0491 | Train MAE: 0.1727 | Train R2: 0.1014 | Val MSE: 0.0436 | Val MAE: 0.1675 | Val R2: 0.0891
# EarlyStopping counter: 1 out of 250
# Epoch 14/10000 | Train MSE: 0.0488 | Train MAE: 0.1729 | Train R2: 0.1081 | Val MSE: 0.0448 | Val MAE: 0.1708 | Val R2: 0.0655
# EarlyStopping counter: 2 out of 250
# Epoch 15/10000 | Train MSE: 0.0490 | Train MAE: 0.1737 | Train R2: 0.1043 | Val MSE: 0.0462 | Val MAE: 0.1742 | Val R2: 0.0361
# EarlyStopping counter: 3 out of 250
# Epoch 16/10000 | Train MSE: 0.0500 | Train MAE: 0.1767 | Train R2: 0.0849 | Val MSE: 0.0473 | Val MAE: 0.1768 | Val R2: 0.0134
# EarlyStopping counter: 4 out of 250
# Epoch 17/10000 | Train MSE: 0.0506 | Train MAE: 0.1788 | Train R2: 0.0746 | Val MSE: 0.0477 | Val MAE: 0.1778 | Val R2: 0.0055
# EarlyStopping counter: 5 out of 250
# Epoch 18/10000 | Train MSE: 0.0507 | Train MAE: 0.1782 | Train R2: 0.0728 | Val MSE: 0.0473 | Val MAE: 0.1771 | Val R2: 0.0133
# EarlyStopping counter: 6 out of 250
# Epoch 19/10000 | Train MSE: 0.0501 | Train MAE: 0.1773 | Train R2: 0.0833 | Val MSE: 0.0464 | Val MAE: 0.1751 | Val R2: 0.0324
# EarlyStopping counter: 7 out of 250
# Epoch 20/10000 | Train MSE: 0.0494 | Train MAE: 0.1762 | Train R2: 0.0964 | Val MSE: 0.0452 | Val MAE: 0.1723 | Val R2: 0.0577
# EarlyStopping counter: 8 out of 250
# Epoch 21/10000 | Train MSE: 0.0485 | Train MAE: 0.1740 | Train R2: 0.1126 | Val MSE: 0.0439 | Val MAE: 0.1693 | Val R2: 0.0837
# EarlyStopping counter: 9 out of 250
# Epoch 22/10000 | Train MSE: 0.0474 | Train MAE: 0.1713 | Train R2: 0.1321 | Val MSE: 0.0428 | Val MAE: 0.1665 | Val R2: 0.1071
# Validation loss decreased (0.043197 --> 0.042784).  Saving model ...
# Epoch 23/10000 | Train MSE: 0.0471 | Train MAE: 0.1699 | Train R2: 0.1378 | Val MSE: 0.0419 | Val MAE: 0.1641 | Val R2: 0.1265
# Validation loss decreased (0.042784 --> 0.041858).  Saving model ...
# Epoch 24/10000 | Train MSE: 0.0466 | Train MAE: 0.1686 | Train R2: 0.1484 | Val MSE: 0.0411 | Val MAE: 0.1620 | Val R2: 0.1415
# Validation loss decreased (0.041858 --> 0.041136).  Saving model ...
# Epoch 25/10000 | Train MSE: 0.0457 | Train MAE: 0.1667 | Train R2: 0.1631 | Val MSE: 0.0406 | Val MAE: 0.1604 | Val R2: 0.1530
# Validation loss decreased (0.041136 --> 0.040585).  Saving model ...
# Epoch 26/10000 | Train MSE: 0.0456 | Train MAE: 0.1658 | Train R2: 0.1651 | Val MSE: 0.0401 | Val MAE: 0.1592 | Val R2: 0.1622
# Validation loss decreased (0.040585 --> 0.040148).  Saving model ...
# Epoch 27/10000 | Train MSE: 0.0453 | Train MAE: 0.1647 | Train R2: 0.1714 | Val MSE: 0.0398 | Val MAE: 0.1582 | Val R2: 0.1699
# Validation loss decreased (0.040148 --> 0.039777).  Saving model ...
# Epoch 28/10000 | Train MSE: 0.0449 | Train MAE: 0.1640 | Train R2: 0.1779 | Val MSE: 0.0394 | Val MAE: 0.1574 | Val R2: 0.1770
# Validation loss decreased (0.039777 --> 0.039438).  Saving model ...
# Epoch 29/10000 | Train MSE: 0.0450 | Train MAE: 0.1642 | Train R2: 0.1773 | Val MSE: 0.0391 | Val MAE: 0.1567 | Val R2: 0.1837
# Validation loss decreased (0.039438 --> 0.039117).  Saving model ...
# Epoch 30/10000 | Train MSE: 0.0443 | Train MAE: 0.1626 | Train R2: 0.1888 | Val MSE: 0.0388 | Val MAE: 0.1562 | Val R2: 0.1897
# Validation loss decreased (0.039117 --> 0.038828).  Saving model ...
# Epoch 31/10000 | Train MSE: 0.0438 | Train MAE: 0.1621 | Train R2: 0.1990 | Val MSE: 0.0386 | Val MAE: 0.1559 | Val R2: 0.1945
# Validation loss decreased (0.038828 --> 0.038599).  Saving model ...
# Epoch 32/10000 | Train MSE: 0.0435 | Train MAE: 0.1613 | Train R2: 0.2044 | Val MSE: 0.0385 | Val MAE: 0.1558 | Val R2: 0.1972
# Validation loss decreased (0.038599 --> 0.038468).  Saving model ...
# Epoch 33/10000 | Train MSE: 0.0432 | Train MAE: 0.1602 | Train R2: 0.2105 | Val MSE: 0.0385 | Val MAE: 0.1561 | Val R2: 0.1970
# EarlyStopping counter: 1 out of 250
# Epoch 34/10000 | Train MSE: 0.0425 | Train MAE: 0.1593 | Train R2: 0.2226 | Val MSE: 0.0386 | Val MAE: 0.1566 | Val R2: 0.1938
# EarlyStopping counter: 2 out of 250
# Epoch 35/10000 | Train MSE: 0.0426 | Train MAE: 0.1593 | Train R2: 0.2207 | Val MSE: 0.0388 | Val MAE: 0.1570 | Val R2: 0.1897
# EarlyStopping counter: 3 out of 250
# Epoch 36/10000 | Train MSE: 0.0430 | Train MAE: 0.1600 | Train R2: 0.2125 | Val MSE: 0.0389 | Val MAE: 0.1571 | Val R2: 0.1885
# EarlyStopping counter: 4 out of 250
# Epoch 37/10000 | Train MSE: 0.0428 | Train MAE: 0.1594 | Train R2: 0.2164 | Val MSE: 0.0387 | Val MAE: 0.1566 | Val R2: 0.1919
# EarlyStopping counter: 5 out of 250
# Epoch 38/10000 | Train MSE: 0.0423 | Train MAE: 0.1586 | Train R2: 0.2259 | Val MSE: 0.0384 | Val MAE: 0.1556 | Val R2: 0.1992
# Validation loss decreased (0.038468 --> 0.038375).  Saving model ...
# Epoch 39/10000 | Train MSE: 0.0418 | Train MAE: 0.1576 | Train R2: 0.2346 | Val MSE: 0.0379 | Val MAE: 0.1544 | Val R2: 0.2082
# Validation loss decreased (0.038375 --> 0.037943).  Saving model ...
# Epoch 40/10000 | Train MSE: 0.0420 | Train MAE: 0.1573 | Train R2: 0.2312 | Val MSE: 0.0375 | Val MAE: 0.1532 | Val R2: 0.2170
# Validation loss decreased (0.037943 --> 0.037523).  Saving model ...
# Epoch 41/10000 | Train MSE: 0.0419 | Train MAE: 0.1575 | Train R2: 0.2329 | Val MSE: 0.0372 | Val MAE: 0.1522 | Val R2: 0.2233
# Validation loss decreased (0.037523 --> 0.037220).  Saving model ...
# Epoch 42/10000 | Train MSE: 0.0419 | Train MAE: 0.1574 | Train R2: 0.2327 | Val MSE: 0.0370 | Val MAE: 0.1515 | Val R2: 0.2271
# Validation loss decreased (0.037220 --> 0.037035).  Saving model ...
# Epoch 43/10000 | Train MSE: 0.0422 | Train MAE: 0.1574 | Train R2: 0.2276 | Val MSE: 0.0369 | Val MAE: 0.1512 | Val R2: 0.2290
# Validation loss decreased (0.037035 --> 0.036947).  Saving model ...
# Epoch 44/10000 | Train MSE: 0.0419 | Train MAE: 0.1562 | Train R2: 0.2340 | Val MSE: 0.0369 | Val MAE: 0.1511 | Val R2: 0.2297
# Validation loss decreased (0.036947 --> 0.036911).  Saving model ...
# Epoch 45/10000 | Train MSE: 0.0421 | Train MAE: 0.1568 | Train R2: 0.2296 | Val MSE: 0.0369 | Val MAE: 0.1511 | Val R2: 0.2292
# EarlyStopping counter: 1 out of 250
# Epoch 46/10000 | Train MSE: 0.0417 | Train MAE: 0.1560 | Train R2: 0.2376 | Val MSE: 0.0370 | Val MAE: 0.1514 | Val R2: 0.2274
# EarlyStopping counter: 2 out of 250
# Epoch 47/10000 | Train MSE: 0.0424 | Train MAE: 0.1568 | Train R2: 0.2241 | Val MSE: 0.0372 | Val MAE: 0.1518 | Val R2: 0.2243
# EarlyStopping counter: 3 out of 250
# Epoch 48/10000 | Train MSE: 0.0417 | Train MAE: 0.1557 | Train R2: 0.2364 | Val MSE: 0.0373 | Val MAE: 0.1522 | Val R2: 0.2216
# EarlyStopping counter: 4 out of 250
# Epoch 49/10000 | Train MSE: 0.0415 | Train MAE: 0.1557 | Train R2: 0.2416 | Val MSE: 0.0373 | Val MAE: 0.1522 | Val R2: 0.2212
# EarlyStopping counter: 5 out of 250
# Epoch 50/10000 | Train MSE: 0.0414 | Train MAE: 0.1550 | Train R2: 0.2425 | Val MSE: 0.0372 | Val MAE: 0.1520 | Val R2: 0.2237
# EarlyStopping counter: 6 out of 250
# Epoch 51/10000 | Train MSE: 0.0416 | Train MAE: 0.1557 | Train R2: 0.2395 | Val MSE: 0.0369 | Val MAE: 0.1513 | Val R2: 0.2292
# EarlyStopping counter: 7 out of 250
# Epoch 52/10000 | Train MSE: 0.0416 | Train MAE: 0.1563 | Train R2: 0.2392 | Val MSE: 0.0366 | Val MAE: 0.1505 | Val R2: 0.2356
# Validation loss decreased (0.036911 --> 0.036628).  Saving model ...
# Epoch 53/10000 | Train MSE: 0.0408 | Train MAE: 0.1541 | Train R2: 0.2533 | Val MSE: 0.0364 | Val MAE: 0.1498 | Val R2: 0.2412
# Validation loss decreased (0.036628 --> 0.036361).  Saving model ...
# Epoch 54/10000 | Train MSE: 0.0409 | Train MAE: 0.1539 | Train R2: 0.2525 | Val MSE: 0.0361 | Val MAE: 0.1492 | Val R2: 0.2458
# Validation loss decreased (0.036361 --> 0.036141).  Saving model ...
# Epoch 55/10000 | Train MSE: 0.0409 | Train MAE: 0.1536 | Train R2: 0.2509 | Val MSE: 0.0360 | Val MAE: 0.1488 | Val R2: 0.2490
# Validation loss decreased (0.036141 --> 0.035988).  Saving model ...
# Epoch 56/10000 | Train MSE: 0.0405 | Train MAE: 0.1538 | Train R2: 0.2584 | Val MSE: 0.0359 | Val MAE: 0.1487 | Val R2: 0.2507
# Validation loss decreased (0.035988 --> 0.035905).  Saving model ...
# Epoch 57/10000 | Train MSE: 0.0404 | Train MAE: 0.1523 | Train R2: 0.2604 | Val MSE: 0.0359 | Val MAE: 0.1487 | Val R2: 0.2516
# Validation loss decreased (0.035905 --> 0.035862).  Saving model ...
# Epoch 58/10000 | Train MSE: 0.0402 | Train MAE: 0.1517 | Train R2: 0.2651 | Val MSE: 0.0359 | Val MAE: 0.1489 | Val R2: 0.2514
# EarlyStopping counter: 1 out of 250
# Epoch 59/10000 | Train MSE: 0.0401 | Train MAE: 0.1522 | Train R2: 0.2658 | Val MSE: 0.0359 | Val MAE: 0.1491 | Val R2: 0.2507
# EarlyStopping counter: 2 out of 250
# Epoch 60/10000 | Train MSE: 0.0397 | Train MAE: 0.1520 | Train R2: 0.2733 | Val MSE: 0.0359 | Val MAE: 0.1492 | Val R2: 0.2512
# EarlyStopping counter: 3 out of 250
# Epoch 61/10000 | Train MSE: 0.0397 | Train MAE: 0.1514 | Train R2: 0.2734 | Val MSE: 0.0357 | Val MAE: 0.1488 | Val R2: 0.2541
# Validation loss decreased (0.035862 --> 0.035743).  Saving model ...
# Epoch 62/10000 | Train MSE: 0.0391 | Train MAE: 0.1506 | Train R2: 0.2845 | Val MSE: 0.0355 | Val MAE: 0.1482 | Val R2: 0.2589
# Validation loss decreased (0.035743 --> 0.035511).  Saving model ...
# Epoch 63/10000 | Train MSE: 0.0398 | Train MAE: 0.1518 | Train R2: 0.2727 | Val MSE: 0.0352 | Val MAE: 0.1472 | Val R2: 0.2654
# Validation loss decreased (0.035511 --> 0.035199).  Saving model ...
# Epoch 64/10000 | Train MSE: 0.0393 | Train MAE: 0.1502 | Train R2: 0.2810 | Val MSE: 0.0349 | Val MAE: 0.1462 | Val R2: 0.2724
# Validation loss decreased (0.035199 --> 0.034867).  Saving model ...
# Epoch 65/10000 | Train MSE: 0.0389 | Train MAE: 0.1498 | Train R2: 0.2875 | Val MSE: 0.0346 | Val MAE: 0.1454 | Val R2: 0.2784
# Validation loss decreased (0.034867 --> 0.034580).  Saving model ...
# Epoch 66/10000 | Train MSE: 0.0386 | Train MAE: 0.1490 | Train R2: 0.2944 | Val MSE: 0.0344 | Val MAE: 0.1448 | Val R2: 0.2824
# Validation loss decreased (0.034580 --> 0.034385).  Saving model ...
# Epoch 67/10000 | Train MSE: 0.0387 | Train MAE: 0.1483 | Train R2: 0.2913 | Val MSE: 0.0343 | Val MAE: 0.1445 | Val R2: 0.2848
# Validation loss decreased (0.034385 --> 0.034271).  Saving model ...
# Epoch 68/10000 | Train MSE: 0.0390 | Train MAE: 0.1484 | Train R2: 0.2866 | Val MSE: 0.0342 | Val MAE: 0.1445 | Val R2: 0.2860
# Validation loss decreased (0.034271 --> 0.034214).  Saving model ...
# Epoch 69/10000 | Train MSE: 0.0378 | Train MAE: 0.1476 | Train R2: 0.3080 | Val MSE: 0.0342 | Val MAE: 0.1446 | Val R2: 0.2865
# Validation loss decreased (0.034214 --> 0.034191).  Saving model ...
# Epoch 70/10000 | Train MSE: 0.0380 | Train MAE: 0.1477 | Train R2: 0.3045 | Val MSE: 0.0342 | Val MAE: 0.1446 | Val R2: 0.2866
# Validation loss decreased (0.034191 --> 0.034185).  Saving model ...
# Epoch 71/10000 | Train MSE: 0.0381 | Train MAE: 0.1476 | Train R2: 0.3025 | Val MSE: 0.0340 | Val MAE: 0.1442 | Val R2: 0.2895
# Validation loss decreased (0.034185 --> 0.034044).  Saving model ...
# Epoch 72/10000 | Train MSE: 0.0376 | Train MAE: 0.1473 | Train R2: 0.3116 | Val MSE: 0.0338 | Val MAE: 0.1433 | Val R2: 0.2952
# Validation loss decreased (0.034044 --> 0.033775).  Saving model ...
# Epoch 73/10000 | Train MSE: 0.0375 | Train MAE: 0.1460 | Train R2: 0.3135 | Val MSE: 0.0335 | Val MAE: 0.1423 | Val R2: 0.3014
# Validation loss decreased (0.033775 --> 0.033476).  Saving model ...
# Epoch 74/10000 | Train MSE: 0.0376 | Train MAE: 0.1461 | Train R2: 0.3117 | Val MSE: 0.0333 | Val MAE: 0.1415 | Val R2: 0.3059
# Validation loss decreased (0.033476 --> 0.033261).  Saving model ...
# Epoch 75/10000 | Train MSE: 0.0369 | Train MAE: 0.1446 | Train R2: 0.3244 | Val MSE: 0.0332 | Val MAE: 0.1411 | Val R2: 0.3076
# Validation loss decreased (0.033261 --> 0.033178).  Saving model ...
# Epoch 76/10000 | Train MSE: 0.0370 | Train MAE: 0.1448 | Train R2: 0.3238 | Val MSE: 0.0332 | Val MAE: 0.1411 | Val R2: 0.3070
# EarlyStopping counter: 1 out of 250
# Epoch 77/10000 | Train MSE: 0.0366 | Train MAE: 0.1442 | Train R2: 0.3311 | Val MSE: 0.0333 | Val MAE: 0.1414 | Val R2: 0.3046
# EarlyStopping counter: 2 out of 250
# Epoch 78/10000 | Train MSE: 0.0366 | Train MAE: 0.1439 | Train R2: 0.3309 | Val MSE: 0.0334 | Val MAE: 0.1417 | Val R2: 0.3020
# EarlyStopping counter: 3 out of 250
# Epoch 79/10000 | Train MSE: 0.0369 | Train MAE: 0.1447 | Train R2: 0.3246 | Val MSE: 0.0334 | Val MAE: 0.1413 | Val R2: 0.3040
# EarlyStopping counter: 4 out of 250
# Epoch 80/10000 | Train MSE: 0.0366 | Train MAE: 0.1441 | Train R2: 0.3301 | Val MSE: 0.0332 | Val MAE: 0.1406 | Val R2: 0.3081
# Validation loss decreased (0.033178 --> 0.033155).  Saving model ...
# Epoch 81/10000 | Train MSE: 0.0369 | Train MAE: 0.1453 | Train R2: 0.3253 | Val MSE: 0.0330 | Val MAE: 0.1402 | Val R2: 0.3106
# Validation loss decreased (0.033155 --> 0.033036).  Saving model ...
# Epoch 82/10000 | Train MSE: 0.0365 | Train MAE: 0.1443 | Train R2: 0.3314 | Val MSE: 0.0330 | Val MAE: 0.1401 | Val R2: 0.3115
# Validation loss decreased (0.033036 --> 0.032990).  Saving model ...
# Epoch 83/10000 | Train MSE: 0.0363 | Train MAE: 0.1443 | Train R2: 0.3365 | Val MSE: 0.0330 | Val MAE: 0.1402 | Val R2: 0.3108
# EarlyStopping counter: 1 out of 250
# Epoch 84/10000 | Train MSE: 0.0362 | Train MAE: 0.1436 | Train R2: 0.3377 | Val MSE: 0.0331 | Val MAE: 0.1405 | Val R2: 0.3100
# EarlyStopping counter: 2 out of 250
# Epoch 85/10000 | Train MSE: 0.0361 | Train MAE: 0.1440 | Train R2: 0.3402 | Val MSE: 0.0331 | Val MAE: 0.1405 | Val R2: 0.3102
# EarlyStopping counter: 3 out of 250
# Epoch 86/10000 | Train MSE: 0.0360 | Train MAE: 0.1434 | Train R2: 0.3406 | Val MSE: 0.0330 | Val MAE: 0.1403 | Val R2: 0.3122
# Validation loss decreased (0.032990 --> 0.032960).  Saving model ...
# Epoch 87/10000 | Train MSE: 0.0360 | Train MAE: 0.1433 | Train R2: 0.3413 | Val MSE: 0.0327 | Val MAE: 0.1396 | Val R2: 0.3166
# Validation loss decreased (0.032960 --> 0.032750).  Saving model ...
# Epoch 88/10000 | Train MSE: 0.0360 | Train MAE: 0.1427 | Train R2: 0.3417 | Val MSE: 0.0326 | Val MAE: 0.1391 | Val R2: 0.3197
# Validation loss decreased (0.032750 --> 0.032598).  Saving model ...
# Epoch 89/10000 | Train MSE: 0.0363 | Train MAE: 0.1435 | Train R2: 0.3360 | Val MSE: 0.0325 | Val MAE: 0.1389 | Val R2: 0.3214
# Validation loss decreased (0.032598 --> 0.032518).  Saving model ...
# Epoch 90/10000 | Train MSE: 0.0363 | Train MAE: 0.1433 | Train R2: 0.3366 | Val MSE: 0.0325 | Val MAE: 0.1389 | Val R2: 0.3216
# Validation loss decreased (0.032518 --> 0.032510).  Saving model ...
# Epoch 91/10000 | Train MSE: 0.0357 | Train MAE: 0.1422 | Train R2: 0.3466 | Val MSE: 0.0326 | Val MAE: 0.1393 | Val R2: 0.3196
# EarlyStopping counter: 1 out of 250
# Epoch 92/10000 | Train MSE: 0.0361 | Train MAE: 0.1431 | Train R2: 0.3395 | Val MSE: 0.0327 | Val MAE: 0.1397 | Val R2: 0.3177
# EarlyStopping counter: 2 out of 250
# Epoch 93/10000 | Train MSE: 0.0356 | Train MAE: 0.1421 | Train R2: 0.3482 | Val MSE: 0.0327 | Val MAE: 0.1398 | Val R2: 0.3177
# EarlyStopping counter: 3 out of 250
# Epoch 94/10000 | Train MSE: 0.0357 | Train MAE: 0.1418 | Train R2: 0.3469 | Val MSE: 0.0326 | Val MAE: 0.1396 | Val R2: 0.3189
# EarlyStopping counter: 4 out of 250
# Epoch 95/10000 | Train MSE: 0.0357 | Train MAE: 0.1427 | Train R2: 0.3471 | Val MSE: 0.0325 | Val MAE: 0.1392 | Val R2: 0.3211
# EarlyStopping counter: 5 out of 250
# Epoch 96/10000 | Train MSE: 0.0361 | Train MAE: 0.1429 | Train R2: 0.3390 | Val MSE: 0.0324 | Val MAE: 0.1387 | Val R2: 0.3235
# Validation loss decreased (0.032510 --> 0.032419).  Saving model ...
# Epoch 97/10000 | Train MSE: 0.0360 | Train MAE: 0.1426 | Train R2: 0.3416 | Val MSE: 0.0323 | Val MAE: 0.1383 | Val R2: 0.3255
# Validation loss decreased (0.032419 --> 0.032319).  Saving model ...
# Epoch 98/10000 | Train MSE: 0.0355 | Train MAE: 0.1417 | Train R2: 0.3498 | Val MSE: 0.0322 | Val MAE: 0.1381 | Val R2: 0.3270
# Validation loss decreased (0.032319 --> 0.032249).  Saving model ...
# Epoch 99/10000 | Train MSE: 0.0361 | Train MAE: 0.1429 | Train R2: 0.3402 | Val MSE: 0.0322 | Val MAE: 0.1381 | Val R2: 0.3270
# Validation loss decreased (0.032249 --> 0.032249).  Saving model ...
# Epoch 100/10000 | Train MSE: 0.0356 | Train MAE: 0.1417 | Train R2: 0.3495 | Val MSE: 0.0323 | Val MAE: 0.1383 | Val R2: 0.3263
# EarlyStopping counter: 1 out of 250
# Epoch 101/10000 | Train MSE: 0.0358 | Train MAE: 0.1421 | Train R2: 0.3449 | Val MSE: 0.0324 | Val MAE: 0.1388 | Val R2: 0.3241
# EarlyStopping counter: 2 out of 250
# Epoch 102/10000 | Train MSE: 0.0350 | Train MAE: 0.1421 | Train R2: 0.3589 | Val MSE: 0.0325 | Val MAE: 0.1391 | Val R2: 0.3224
# EarlyStopping counter: 3 out of 250
# Epoch 103/10000 | Train MSE: 0.0355 | Train MAE: 0.1418 | Train R2: 0.3512 | Val MSE: 0.0325 | Val MAE: 0.1391 | Val R2: 0.3224
# EarlyStopping counter: 4 out of 250
# Epoch 104/10000 | Train MSE: 0.0357 | Train MAE: 0.1428 | Train R2: 0.3464 | Val MSE: 0.0324 | Val MAE: 0.1389 | Val R2: 0.3239
# EarlyStopping counter: 5 out of 250
# Epoch 105/10000 | Train MSE: 0.0360 | Train MAE: 0.1432 | Train R2: 0.3419 | Val MSE: 0.0323 | Val MAE: 0.1385 | Val R2: 0.3265
# EarlyStopping counter: 6 out of 250
# Epoch 106/10000 | Train MSE: 0.0356 | Train MAE: 0.1415 | Train R2: 0.3492 | Val MSE: 0.0321 | Val MAE: 0.1380 | Val R2: 0.3292
# Validation loss decreased (0.032249 --> 0.032143).  Saving model ...
# Epoch 107/10000 | Train MSE: 0.0358 | Train MAE: 0.1424 | Train R2: 0.3453 | Val MSE: 0.0321 | Val MAE: 0.1377 | Val R2: 0.3310
# Validation loss decreased (0.032143 --> 0.032057).  Saving model ...
# Epoch 108/10000 | Train MSE: 0.0354 | Train MAE: 0.1415 | Train R2: 0.3528 | Val MSE: 0.0320 | Val MAE: 0.1377 | Val R2: 0.3317
# Validation loss decreased (0.032057 --> 0.032022).  Saving model ...
# Epoch 109/10000 | Train MSE: 0.0355 | Train MAE: 0.1412 | Train R2: 0.3498 | Val MSE: 0.0321 | Val MAE: 0.1380 | Val R2: 0.3302
# EarlyStopping counter: 1 out of 250
# Epoch 110/10000 | Train MSE: 0.0350 | Train MAE: 0.1415 | Train R2: 0.3601 | Val MSE: 0.0322 | Val MAE: 0.1384 | Val R2: 0.3278
# EarlyStopping counter: 2 out of 250
# Epoch 111/10000 | Train MSE: 0.0348 | Train MAE: 0.1400 | Train R2: 0.3626 | Val MSE: 0.0323 | Val MAE: 0.1386 | Val R2: 0.3268
# EarlyStopping counter: 3 out of 250
# Epoch 112/10000 | Train MSE: 0.0348 | Train MAE: 0.1402 | Train R2: 0.3640 | Val MSE: 0.0322 | Val MAE: 0.1384 | Val R2: 0.3285
# EarlyStopping counter: 4 out of 250
# Epoch 113/10000 | Train MSE: 0.0350 | Train MAE: 0.1410 | Train R2: 0.3589 | Val MSE: 0.0320 | Val MAE: 0.1380 | Val R2: 0.3314
# EarlyStopping counter: 5 out of 250
# Epoch 114/10000 | Train MSE: 0.0349 | Train MAE: 0.1401 | Train R2: 0.3616 | Val MSE: 0.0319 | Val MAE: 0.1374 | Val R2: 0.3352
# Validation loss decreased (0.032022 --> 0.031855).  Saving model ...
# Epoch 115/10000 | Train MSE: 0.0347 | Train MAE: 0.1399 | Train R2: 0.3653 | Val MSE: 0.0317 | Val MAE: 0.1370 | Val R2: 0.3378
# Validation loss decreased (0.031855 --> 0.031734).  Saving model ...
# Epoch 116/10000 | Train MSE: 0.0343 | Train MAE: 0.1405 | Train R2: 0.3730 | Val MSE: 0.0317 | Val MAE: 0.1369 | Val R2: 0.3386
# Validation loss decreased (0.031734 --> 0.031693).  Saving model ...
# Epoch 117/10000 | Train MSE: 0.0349 | Train MAE: 0.1406 | Train R2: 0.3619 | Val MSE: 0.0317 | Val MAE: 0.1370 | Val R2: 0.3387
# Validation loss decreased (0.031693 --> 0.031687).  Saving model ...
# Epoch 118/10000 | Train MSE: 0.0346 | Train MAE: 0.1413 | Train R2: 0.3665 | Val MSE: 0.0317 | Val MAE: 0.1370 | Val R2: 0.3391
# Validation loss decreased (0.031687 --> 0.031670).  Saving model ...
# Epoch 119/10000 | Train MSE: 0.0347 | Train MAE: 0.1404 | Train R2: 0.3655 | Val MSE: 0.0317 | Val MAE: 0.1371 | Val R2: 0.3388
# EarlyStopping counter: 1 out of 250
# Epoch 120/10000 | Train MSE: 0.0345 | Train MAE: 0.1405 | Train R2: 0.3684 | Val MSE: 0.0317 | Val MAE: 0.1372 | Val R2: 0.3389
# EarlyStopping counter: 2 out of 250
# Epoch 121/10000 | Train MSE: 0.0355 | Train MAE: 0.1420 | Train R2: 0.3499 | Val MSE: 0.0316 | Val MAE: 0.1372 | Val R2: 0.3396
# Validation loss decreased (0.031670 --> 0.031645).  Saving model ...
# Epoch 122/10000 | Train MSE: 0.0345 | Train MAE: 0.1409 | Train R2: 0.3686 | Val MSE: 0.0315 | Val MAE: 0.1369 | Val R2: 0.3416
# Validation loss decreased (0.031645 --> 0.031548).  Saving model ...
# Epoch 123/10000 | Train MSE: 0.0346 | Train MAE: 0.1403 | Train R2: 0.3670 | Val MSE: 0.0315 | Val MAE: 0.1366 | Val R2: 0.3435
# Validation loss decreased (0.031548 --> 0.031456).  Saving model ...
# Epoch 124/10000 | Train MSE: 0.0344 | Train MAE: 0.1395 | Train R2: 0.3711 | Val MSE: 0.0314 | Val MAE: 0.1365 | Val R2: 0.3444
# Validation loss decreased (0.031456 --> 0.031413).  Saving model ...
# Epoch 125/10000 | Train MSE: 0.0341 | Train MAE: 0.1396 | Train R2: 0.3758 | Val MSE: 0.0314 | Val MAE: 0.1365 | Val R2: 0.3445
# Validation loss decreased (0.031413 --> 0.031409).  Saving model ...
# Epoch 126/10000 | Train MSE: 0.0344 | Train MAE: 0.1391 | Train R2: 0.3706 | Val MSE: 0.0315 | Val MAE: 0.1368 | Val R2: 0.3429
# EarlyStopping counter: 1 out of 250
# Epoch 127/10000 | Train MSE: 0.0344 | Train MAE: 0.1402 | Train R2: 0.3713 | Val MSE: 0.0315 | Val MAE: 0.1370 | Val R2: 0.3418
# EarlyStopping counter: 2 out of 250
# Epoch 128/10000 | Train MSE: 0.0345 | Train MAE: 0.1409 | Train R2: 0.3683 | Val MSE: 0.0316 | Val MAE: 0.1370 | Val R2: 0.3415
# EarlyStopping counter: 3 out of 250
# Epoch 129/10000 | Train MSE: 0.0338 | Train MAE: 0.1394 | Train R2: 0.3815 | Val MSE: 0.0315 | Val MAE: 0.1369 | Val R2: 0.3426
# EarlyStopping counter: 4 out of 250
# Epoch 130/10000 | Train MSE: 0.0340 | Train MAE: 0.1389 | Train R2: 0.3775 | Val MSE: 0.0314 | Val MAE: 0.1366 | Val R2: 0.3447
# Validation loss decreased (0.031409 --> 0.031399).  Saving model ...
# Epoch 131/10000 | Train MSE: 0.0339 | Train MAE: 0.1384 | Train R2: 0.3799 | Val MSE: 0.0313 | Val MAE: 0.1363 | Val R2: 0.3464
# Validation loss decreased (0.031399 --> 0.031320).  Saving model ...
# Epoch 132/10000 | Train MSE: 0.0340 | Train MAE: 0.1395 | Train R2: 0.3775 | Val MSE: 0.0313 | Val MAE: 0.1363 | Val R2: 0.3468
# Validation loss decreased (0.031320 --> 0.031301).  Saving model ...
# Epoch 133/10000 | Train MSE: 0.0337 | Train MAE: 0.1398 | Train R2: 0.3827 | Val MSE: 0.0313 | Val MAE: 0.1364 | Val R2: 0.3463
# EarlyStopping counter: 1 out of 250
# Epoch 134/10000 | Train MSE: 0.0342 | Train MAE: 0.1393 | Train R2: 0.3735 | Val MSE: 0.0314 | Val MAE: 0.1366 | Val R2: 0.3447
# EarlyStopping counter: 2 out of 250
# Epoch 135/10000 | Train MSE: 0.0339 | Train MAE: 0.1391 | Train R2: 0.3794 | Val MSE: 0.0314 | Val MAE: 0.1366 | Val R2: 0.3452
# EarlyStopping counter: 3 out of 250
# Epoch 136/10000 | Train MSE: 0.0343 | Train MAE: 0.1407 | Train R2: 0.3731 | Val MSE: 0.0313 | Val MAE: 0.1364 | Val R2: 0.3466
# EarlyStopping counter: 4 out of 250
# Epoch 137/10000 | Train MSE: 0.0339 | Train MAE: 0.1401 | Train R2: 0.3802 | Val MSE: 0.0312 | Val MAE: 0.1361 | Val R2: 0.3488
# Validation loss decreased (0.031301 --> 0.031206).  Saving model ...
# Epoch 138/10000 | Train MSE: 0.0333 | Train MAE: 0.1381 | Train R2: 0.3907 | Val MSE: 0.0311 | Val MAE: 0.1359 | Val R2: 0.3504
# Validation loss decreased (0.031206 --> 0.031128).  Saving model ...
# Epoch 139/10000 | Train MSE: 0.0333 | Train MAE: 0.1377 | Train R2: 0.3912 | Val MSE: 0.0311 | Val MAE: 0.1357 | Val R2: 0.3517
# Validation loss decreased (0.031128 --> 0.031065).  Saving model ...
# Epoch 140/10000 | Train MSE: 0.0342 | Train MAE: 0.1398 | Train R2: 0.3744 | Val MSE: 0.0310 | Val MAE: 0.1356 | Val R2: 0.3525
# Validation loss decreased (0.031065 --> 0.031028).  Saving model ...
# Epoch 141/10000 | Train MSE: 0.0331 | Train MAE: 0.1385 | Train R2: 0.3946 | Val MSE: 0.0310 | Val MAE: 0.1357 | Val R2: 0.3520
# EarlyStopping counter: 1 out of 250
# Epoch 142/10000 | Train MSE: 0.0332 | Train MAE: 0.1376 | Train R2: 0.3921 | Val MSE: 0.0312 | Val MAE: 0.1361 | Val R2: 0.3494
# EarlyStopping counter: 2 out of 250
# Epoch 143/10000 | Train MSE: 0.0335 | Train MAE: 0.1393 | Train R2: 0.3879 | Val MSE: 0.0313 | Val MAE: 0.1364 | Val R2: 0.3475
# EarlyStopping counter: 3 out of 250
# Epoch 144/10000 | Train MSE: 0.0330 | Train MAE: 0.1370 | Train R2: 0.3962 | Val MSE: 0.0313 | Val MAE: 0.1365 | Val R2: 0.3469
# EarlyStopping counter: 4 out of 250
# Epoch 145/10000 | Train MSE: 0.0332 | Train MAE: 0.1384 | Train R2: 0.3928 | Val MSE: 0.0312 | Val MAE: 0.1363 | Val R2: 0.3481
# EarlyStopping counter: 5 out of 250
# Epoch 146/10000 | Train MSE: 0.0336 | Train MAE: 0.1393 | Train R2: 0.3861 | Val MSE: 0.0312 | Val MAE: 0.1361 | Val R2: 0.3495
# EarlyStopping counter: 6 out of 250
# Epoch 147/10000 | Train MSE: 0.0332 | Train MAE: 0.1382 | Train R2: 0.3925 | Val MSE: 0.0311 | Val MAE: 0.1360 | Val R2: 0.3503
# EarlyStopping counter: 7 out of 250
# Epoch 148/10000 | Train MSE: 0.0332 | Train MAE: 0.1381 | Train R2: 0.3935 | Val MSE: 0.0311 | Val MAE: 0.1359 | Val R2: 0.3504
# EarlyStopping counter: 8 out of 250
# Epoch 149/10000 | Train MSE: 0.0332 | Train MAE: 0.1385 | Train R2: 0.3929 | Val MSE: 0.0312 | Val MAE: 0.1360 | Val R2: 0.3498
# EarlyStopping counter: 9 out of 250
# Epoch 150/10000 | Train MSE: 0.0330 | Train MAE: 0.1380 | Train R2: 0.3967 | Val MSE: 0.0312 | Val MAE: 0.1361 | Val R2: 0.3493
# EarlyStopping counter: 10 out of 250
# Epoch 151/10000 | Train MSE: 0.0329 | Train MAE: 0.1372 | Train R2: 0.3989 | Val MSE: 0.0312 | Val MAE: 0.1361 | Val R2: 0.3489
# EarlyStopping counter: 11 out of 250
# Epoch 152/10000 | Train MSE: 0.0329 | Train MAE: 0.1378 | Train R2: 0.3983 | Val MSE: 0.0312 | Val MAE: 0.1361 | Val R2: 0.3489
# EarlyStopping counter: 12 out of 250
# Epoch 153/10000 | Train MSE: 0.0330 | Train MAE: 0.1381 | Train R2: 0.3970 | Val MSE: 0.0312 | Val MAE: 0.1360 | Val R2: 0.3490
# EarlyStopping counter: 13 out of 250
# Epoch 154/10000 | Train MSE: 0.0326 | Train MAE: 0.1374 | Train R2: 0.4031 | Val MSE: 0.0312 | Val MAE: 0.1360 | Val R2: 0.3486
# EarlyStopping counter: 14 out of 250
# Epoch 155/10000 | Train MSE: 0.0331 | Train MAE: 0.1380 | Train R2: 0.3940 | Val MSE: 0.0313 | Val MAE: 0.1361 | Val R2: 0.3476
# EarlyStopping counter: 15 out of 250
# Epoch 156/10000 | Train MSE: 0.0330 | Train MAE: 0.1378 | Train R2: 0.3956 | Val MSE: 0.0313 | Val MAE: 0.1361 | Val R2: 0.3477
# EarlyStopping counter: 16 out of 250
# Epoch 157/10000 | Train MSE: 0.0330 | Train MAE: 0.1374 | Train R2: 0.3954 | Val MSE: 0.0313 | Val MAE: 0.1361 | Val R2: 0.3475
# EarlyStopping counter: 17 out of 250
# Epoch 158/10000 | Train MSE: 0.0326 | Train MAE: 0.1367 | Train R2: 0.4033 | Val MSE: 0.0313 | Val MAE: 0.1362 | Val R2: 0.3471
# EarlyStopping counter: 18 out of 250
# Epoch 159/10000 | Train MSE: 0.0318 | Train MAE: 0.1365 | Train R2: 0.4176 | Val MSE: 0.0313 | Val MAE: 0.1362 | Val R2: 0.3472
# EarlyStopping counter: 19 out of 250
# Epoch 160/10000 | Train MSE: 0.0322 | Train MAE: 0.1361 | Train R2: 0.4112 | Val MSE: 0.0313 | Val MAE: 0.1362 | Val R2: 0.3470
# EarlyStopping counter: 20 out of 250
# Epoch 161/10000 | Train MSE: 0.0324 | Train MAE: 0.1363 | Train R2: 0.4077 | Val MSE: 0.0313 | Val MAE: 0.1364 | Val R2: 0.3461
# EarlyStopping counter: 21 out of 250
# Epoch 162/10000 | Train MSE: 0.0327 | Train MAE: 0.1372 | Train R2: 0.4015 | Val MSE: 0.0314 | Val MAE: 0.1365 | Val R2: 0.3454
# EarlyStopping counter: 22 out of 250
# Epoch 163/10000 | Train MSE: 0.0323 | Train MAE: 0.1365 | Train R2: 0.4097 | Val MSE: 0.0314 | Val MAE: 0.1367 | Val R2: 0.3441
# EarlyStopping counter: 23 out of 250
# Epoch 164/10000 | Train MSE: 0.0325 | Train MAE: 0.1365 | Train R2: 0.4049 | Val MSE: 0.0314 | Val MAE: 0.1366 | Val R2: 0.3441
# EarlyStopping counter: 24 out of 250
# Epoch 165/10000 | Train MSE: 0.0321 | Train MAE: 0.1365 | Train R2: 0.4119 | Val MSE: 0.0314 | Val MAE: 0.1366 | Val R2: 0.3438
# EarlyStopping counter: 25 out of 250
# Epoch 166/10000 | Train MSE: 0.0321 | Train MAE: 0.1365 | Train R2: 0.4122 | Val MSE: 0.0315 | Val MAE: 0.1367 | Val R2: 0.3432
# EarlyStopping counter: 26 out of 250
# Epoch 167/10000 | Train MSE: 0.0321 | Train MAE: 0.1365 | Train R2: 0.4131 | Val MSE: 0.0315 | Val MAE: 0.1367 | Val R2: 0.3436
# EarlyStopping counter: 27 out of 250
# Epoch 168/10000 | Train MSE: 0.0321 | Train MAE: 0.1365 | Train R2: 0.4132 | Val MSE: 0.0315 | Val MAE: 0.1366 | Val R2: 0.3436
# EarlyStopping counter: 28 out of 250
# Epoch 169/10000 | Train MSE: 0.0321 | Train MAE: 0.1370 | Train R2: 0.4120 | Val MSE: 0.0315 | Val MAE: 0.1367 | Val R2: 0.3431
# EarlyStopping counter: 29 out of 250
# Epoch 170/10000 | Train MSE: 0.0322 | Train MAE: 0.1366 | Train R2: 0.4112 | Val MSE: 0.0315 | Val MAE: 0.1368 | Val R2: 0.3417
# EarlyStopping counter: 30 out of 250
# Epoch 171/10000 | Train MSE: 0.0319 | Train MAE: 0.1359 | Train R2: 0.4161 | Val MSE: 0.0316 | Val MAE: 0.1369 | Val R2: 0.3411
# EarlyStopping counter: 31 out of 250
# Epoch 172/10000 | Train MSE: 0.0325 | Train MAE: 0.1377 | Train R2: 0.4056 | Val MSE: 0.0315 | Val MAE: 0.1369 | Val R2: 0.3416
# EarlyStopping counter: 32 out of 250
# Epoch 173/10000 | Train MSE: 0.0319 | Train MAE: 0.1361 | Train R2: 0.4169 | Val MSE: 0.0315 | Val MAE: 0.1368 | Val R2: 0.3421
# EarlyStopping counter: 33 out of 250
# Epoch 174/10000 | Train MSE: 0.0314 | Train MAE: 0.1347 | Train R2: 0.4247 | Val MSE: 0.0315 | Val MAE: 0.1367 | Val R2: 0.3428
# EarlyStopping counter: 34 out of 250
# Epoch 175/10000 | Train MSE: 0.0319 | Train MAE: 0.1360 | Train R2: 0.4166 | Val MSE: 0.0315 | Val MAE: 0.1368 | Val R2: 0.3418
# EarlyStopping counter: 35 out of 250
# Epoch 176/10000 | Train MSE: 0.0316 | Train MAE: 0.1350 | Train R2: 0.4210 | Val MSE: 0.0317 | Val MAE: 0.1371 | Val R2: 0.3387
# EarlyStopping counter: 36 out of 250
# Epoch 177/10000 | Train MSE: 0.0318 | Train MAE: 0.1351 | Train R2: 0.4183 | Val MSE: 0.0318 | Val MAE: 0.1374 | Val R2: 0.3358
# EarlyStopping counter: 37 out of 250
# Epoch 178/10000 | Train MSE: 0.0320 | Train MAE: 0.1350 | Train R2: 0.4150 | Val MSE: 0.0318 | Val MAE: 0.1372 | Val R2: 0.3368
# EarlyStopping counter: 38 out of 250
# Epoch 179/10000 | Train MSE: 0.0317 | Train MAE: 0.1360 | Train R2: 0.4204 | Val MSE: 0.0317 | Val MAE: 0.1368 | Val R2: 0.3391
# EarlyStopping counter: 39 out of 250
# Epoch 180/10000 | Train MSE: 0.0318 | Train MAE: 0.1364 | Train R2: 0.4176 | Val MSE: 0.0317 | Val MAE: 0.1368 | Val R2: 0.3391
# EarlyStopping counter: 40 out of 250
# Epoch 181/10000 | Train MSE: 0.0315 | Train MAE: 0.1348 | Train R2: 0.4231 | Val MSE: 0.0318 | Val MAE: 0.1370 | Val R2: 0.3372
# EarlyStopping counter: 41 out of 250
# Epoch 182/10000 | Train MSE: 0.0314 | Train MAE: 0.1349 | Train R2: 0.4263 | Val MSE: 0.0318 | Val MAE: 0.1371 | Val R2: 0.3355
# EarlyStopping counter: 42 out of 250
# Epoch 183/10000 | Train MSE: 0.0310 | Train MAE: 0.1335 | Train R2: 0.4331 | Val MSE: 0.0319 | Val MAE: 0.1373 | Val R2: 0.3341
# EarlyStopping counter: 43 out of 250
# Epoch 184/10000 | Train MSE: 0.0315 | Train MAE: 0.1358 | Train R2: 0.4246 | Val MSE: 0.0318 | Val MAE: 0.1371 | Val R2: 0.3356
# EarlyStopping counter: 44 out of 250
# Epoch 185/10000 | Train MSE: 0.0304 | Train MAE: 0.1339 | Train R2: 0.4444 | Val MSE: 0.0317 | Val MAE: 0.1366 | Val R2: 0.3393
# EarlyStopping counter: 45 out of 250
# Epoch 186/10000 | Train MSE: 0.0305 | Train MAE: 0.1326 | Train R2: 0.4415 | Val MSE: 0.0316 | Val MAE: 0.1363 | Val R2: 0.3410
# EarlyStopping counter: 46 out of 250
# Epoch 187/10000 | Train MSE: 0.0314 | Train MAE: 0.1343 | Train R2: 0.4248 | Val MSE: 0.0316 | Val MAE: 0.1364 | Val R2: 0.3399
# EarlyStopping counter: 47 out of 250
# Epoch 188/10000 | Train MSE: 0.0311 | Train MAE: 0.1332 | Train R2: 0.4312 | Val MSE: 0.0318 | Val MAE: 0.1368 | Val R2: 0.3362
# EarlyStopping counter: 48 out of 250
# Epoch 189/10000 | Train MSE: 0.0308 | Train MAE: 0.1331 | Train R2: 0.4361 | Val MSE: 0.0320 | Val MAE: 0.1372 | Val R2: 0.3324
# EarlyStopping counter: 49 out of 250
# Epoch 190/10000 | Train MSE: 0.0306 | Train MAE: 0.1327 | Train R2: 0.4411 | Val MSE: 0.0321 | Val MAE: 0.1374 | Val R2: 0.3300
# EarlyStopping counter: 50 out of 250
# Epoch 191/10000 | Train MSE: 0.0311 | Train MAE: 0.1342 | Train R2: 0.4308 | Val MSE: 0.0321 | Val MAE: 0.1372 | Val R2: 0.3302
# EarlyStopping counter: 51 out of 250
# Epoch 192/10000 | Train MSE: 0.0306 | Train MAE: 0.1327 | Train R2: 0.4395 | Val MSE: 0.0321 | Val MAE: 0.1371 | Val R2: 0.3301
# EarlyStopping counter: 52 out of 250
# Epoch 193/10000 | Train MSE: 0.0306 | Train MAE: 0.1320 | Train R2: 0.4400 | Val MSE: 0.0321 | Val MAE: 0.1370 | Val R2: 0.3299
# EarlyStopping counter: 53 out of 250
# Epoch 194/10000 | Train MSE: 0.0308 | Train MAE: 0.1337 | Train R2: 0.4360 | Val MSE: 0.0322 | Val MAE: 0.1370 | Val R2: 0.3291
# EarlyStopping counter: 54 out of 250
# Epoch 195/10000 | Train MSE: 0.0304 | Train MAE: 0.1324 | Train R2: 0.4431 | Val MSE: 0.0322 | Val MAE: 0.1371 | Val R2: 0.3283
# EarlyStopping counter: 55 out of 250
# Epoch 196/10000 | Train MSE: 0.0302 | Train MAE: 0.1323 | Train R2: 0.4484 | Val MSE: 0.0324 | Val MAE: 0.1377 | Val R2: 0.3234
# EarlyStopping counter: 56 out of 250
# Epoch 197/10000 | Train MSE: 0.0306 | Train MAE: 0.1329 | Train R2: 0.4408 | Val MSE: 0.0325 | Val MAE: 0.1379 | Val R2: 0.3209
# EarlyStopping counter: 57 out of 250
# Epoch 198/10000 | Train MSE: 0.0308 | Train MAE: 0.1329 | Train R2: 0.4369 | Val MSE: 0.0324 | Val MAE: 0.1375 | Val R2: 0.3244
# EarlyStopping counter: 58 out of 250
# Epoch 199/10000 | Train MSE: 0.0294 | Train MAE: 0.1311 | Train R2: 0.4625 | Val MSE: 0.0321 | Val MAE: 0.1368 | Val R2: 0.3305
# EarlyStopping counter: 59 out of 250
# Epoch 200/10000 | Train MSE: 0.0305 | Train MAE: 0.1325 | Train R2: 0.4413 | Val MSE: 0.0320 | Val MAE: 0.1366 | Val R2: 0.3316
# EarlyStopping counter: 60 out of 250
# Epoch 201/10000 | Train MSE: 0.0297 | Train MAE: 0.1318 | Train R2: 0.4561 | Val MSE: 0.0321 | Val MAE: 0.1368 | Val R2: 0.3293
# EarlyStopping counter: 61 out of 250
# Epoch 202/10000 | Train MSE: 0.0303 | Train MAE: 0.1334 | Train R2: 0.4457 | Val MSE: 0.0325 | Val MAE: 0.1376 | Val R2: 0.3223
# EarlyStopping counter: 62 out of 250
# Epoch 203/10000 | Train MSE: 0.0302 | Train MAE: 0.1336 | Train R2: 0.4475 | Val MSE: 0.0327 | Val MAE: 0.1380 | Val R2: 0.3178
# EarlyStopping counter: 63 out of 250
# Epoch 204/10000 | Train MSE: 0.0306 | Train MAE: 0.1331 | Train R2: 0.4407 | Val MSE: 0.0326 | Val MAE: 0.1379 | Val R2: 0.3188
# EarlyStopping counter: 64 out of 250
# Epoch 205/10000 | Train MSE: 0.0302 | Train MAE: 0.1313 | Train R2: 0.4480 | Val MSE: 0.0325 | Val MAE: 0.1374 | Val R2: 0.3226
# EarlyStopping counter: 65 out of 250
# Epoch 206/10000 | Train MSE: 0.0298 | Train MAE: 0.1310 | Train R2: 0.4555 | Val MSE: 0.0323 | Val MAE: 0.1370 | Val R2: 0.3253
# EarlyStopping counter: 66 out of 250
# Epoch 207/10000 | Train MSE: 0.0297 | Train MAE: 0.1297 | Train R2: 0.4570 | Val MSE: 0.0324 | Val MAE: 0.1371 | Val R2: 0.3238
# EarlyStopping counter: 67 out of 250
# Epoch 208/10000 | Train MSE: 0.0302 | Train MAE: 0.1324 | Train R2: 0.4468 | Val MSE: 0.0326 | Val MAE: 0.1378 | Val R2: 0.3195
# EarlyStopping counter: 68 out of 250
# Epoch 209/10000 | Train MSE: 0.0295 | Train MAE: 0.1312 | Train R2: 0.4609 | Val MSE: 0.0329 | Val MAE: 0.1386 | Val R2: 0.3128
# EarlyStopping counter: 69 out of 250
# Epoch 210/10000 | Train MSE: 0.0297 | Train MAE: 0.1312 | Train R2: 0.4560 | Val MSE: 0.0329 | Val MAE: 0.1386 | Val R2: 0.3133
# EarlyStopping counter: 70 out of 250
# Epoch 211/10000 | Train MSE: 0.0292 | Train MAE: 0.1316 | Train R2: 0.4653 | Val MSE: 0.0327 | Val MAE: 0.1377 | Val R2: 0.3181
# EarlyStopping counter: 71 out of 250
# Epoch 212/10000 | Train MSE: 0.0289 | Train MAE: 0.1300 | Train R2: 0.4722 | Val MSE: 0.0326 | Val MAE: 0.1373 | Val R2: 0.3195
# EarlyStopping counter: 72 out of 250
# Epoch 213/10000 | Train MSE: 0.0292 | Train MAE: 0.1302 | Train R2: 0.4659 | Val MSE: 0.0328 | Val MAE: 0.1376 | Val R2: 0.3152
# EarlyStopping counter: 73 out of 250
# Epoch 214/10000 | Train MSE: 0.0295 | Train MAE: 0.1311 | Train R2: 0.4599 | Val MSE: 0.0332 | Val MAE: 0.1387 | Val R2: 0.3063
# EarlyStopping counter: 74 out of 250
# Epoch 215/10000 | Train MSE: 0.0289 | Train MAE: 0.1305 | Train R2: 0.4705 | Val MSE: 0.0338 | Val MAE: 0.1400 | Val R2: 0.2942
# EarlyStopping counter: 75 out of 250
# Epoch 216/10000 | Train MSE: 0.0290 | Train MAE: 0.1301 | Train R2: 0.4699 | Val MSE: 0.0339 | Val MAE: 0.1402 | Val R2: 0.2922
# EarlyStopping counter: 76 out of 250
# Epoch 217/10000 | Train MSE: 0.0293 | Train MAE: 0.1311 | Train R2: 0.4631 | Val MSE: 0.0336 | Val MAE: 0.1392 | Val R2: 0.2992
# EarlyStopping counter: 77 out of 250
# Epoch 218/10000 | Train MSE: 0.0288 | Train MAE: 0.1282 | Train R2: 0.4738 | Val MSE: 0.0332 | Val MAE: 0.1383 | Val R2: 0.3066
# EarlyStopping counter: 78 out of 250
# Epoch 219/10000 | Train MSE: 0.0290 | Train MAE: 0.1292 | Train R2: 0.4702 | Val MSE: 0.0331 | Val MAE: 0.1379 | Val R2: 0.3091
# EarlyStopping counter: 79 out of 250
# Epoch 220/10000 | Train MSE: 0.0293 | Train MAE: 0.1307 | Train R2: 0.4639 | Val MSE: 0.0332 | Val MAE: 0.1381 | Val R2: 0.3082
# EarlyStopping counter: 80 out of 250
# Epoch 221/10000 | Train MSE: 0.0289 | Train MAE: 0.1295 | Train R2: 0.4714 | Val MSE: 0.0332 | Val MAE: 0.1383 | Val R2: 0.3073
# EarlyStopping counter: 81 out of 250
# Epoch 222/10000 | Train MSE: 0.0288 | Train MAE: 0.1304 | Train R2: 0.4739 | Val MSE: 0.0329 | Val MAE: 0.1375 | Val R2: 0.3124
# EarlyStopping counter: 82 out of 250
# Epoch 223/10000 | Train MSE: 0.0285 | Train MAE: 0.1280 | Train R2: 0.4793 | Val MSE: 0.0328 | Val MAE: 0.1370 | Val R2: 0.3158
# EarlyStopping counter: 83 out of 250
# Epoch 224/10000 | Train MSE: 0.0289 | Train MAE: 0.1298 | Train R2: 0.4719 | Val MSE: 0.0328 | Val MAE: 0.1370 | Val R2: 0.3159
# EarlyStopping counter: 84 out of 250
# Epoch 225/10000 | Train MSE: 0.0293 | Train MAE: 0.1303 | Train R2: 0.4635 | Val MSE: 0.0329 | Val MAE: 0.1375 | Val R2: 0.3124
# EarlyStopping counter: 85 out of 250
# Epoch 226/10000 | Train MSE: 0.0283 | Train MAE: 0.1284 | Train R2: 0.4829 | Val MSE: 0.0333 | Val MAE: 0.1385 | Val R2: 0.3047
# EarlyStopping counter: 86 out of 250
# Epoch 227/10000 | Train MSE: 0.0289 | Train MAE: 0.1291 | Train R2: 0.4722 | Val MSE: 0.0337 | Val MAE: 0.1396 | Val R2: 0.2968
# EarlyStopping counter: 87 out of 250
# Epoch 228/10000 | Train MSE: 0.0285 | Train MAE: 0.1288 | Train R2: 0.4792 | Val MSE: 0.0336 | Val MAE: 0.1393 | Val R2: 0.2988
# EarlyStopping counter: 88 out of 250
# Epoch 229/10000 | Train MSE: 0.0274 | Train MAE: 0.1267 | Train R2: 0.4993 | Val MSE: 0.0333 | Val MAE: 0.1384 | Val R2: 0.3049
# EarlyStopping counter: 89 out of 250
# Epoch 230/10000 | Train MSE: 0.0285 | Train MAE: 0.1281 | Train R2: 0.4782 | Val MSE: 0.0331 | Val MAE: 0.1377 | Val R2: 0.3084
# EarlyStopping counter: 90 out of 250
# Epoch 231/10000 | Train MSE: 0.0280 | Train MAE: 0.1266 | Train R2: 0.4871 | Val MSE: 0.0332 | Val MAE: 0.1378 | Val R2: 0.3063
# EarlyStopping counter: 91 out of 250
# Epoch 232/10000 | Train MSE: 0.0276 | Train MAE: 0.1272 | Train R2: 0.4952 | Val MSE: 0.0336 | Val MAE: 0.1386 | Val R2: 0.2983
# EarlyStopping counter: 92 out of 250
# Epoch 233/10000 | Train MSE: 0.0280 | Train MAE: 0.1271 | Train R2: 0.4872 | Val MSE: 0.0339 | Val MAE: 0.1392 | Val R2: 0.2933
# EarlyStopping counter: 93 out of 250
# Epoch 234/10000 | Train MSE: 0.0271 | Train MAE: 0.1264 | Train R2: 0.5049 | Val MSE: 0.0338 | Val MAE: 0.1390 | Val R2: 0.2941
# EarlyStopping counter: 94 out of 250
# Epoch 235/10000 | Train MSE: 0.0284 | Train MAE: 0.1290 | Train R2: 0.4813 | Val MSE: 0.0336 | Val MAE: 0.1382 | Val R2: 0.2988
# EarlyStopping counter: 95 out of 250
# Epoch 236/10000 | Train MSE: 0.0273 | Train MAE: 0.1271 | Train R2: 0.5010 | Val MSE: 0.0335 | Val MAE: 0.1378 | Val R2: 0.3004
# EarlyStopping counter: 96 out of 250
# Epoch 237/10000 | Train MSE: 0.0272 | Train MAE: 0.1255 | Train R2: 0.5029 | Val MSE: 0.0336 | Val MAE: 0.1379 | Val R2: 0.2986
# EarlyStopping counter: 97 out of 250
# Epoch 238/10000 | Train MSE: 0.0282 | Train MAE: 0.1281 | Train R2: 0.4833 | Val MSE: 0.0338 | Val MAE: 0.1382 | Val R2: 0.2956
# EarlyStopping counter: 98 out of 250
# Epoch 239/10000 | Train MSE: 0.0276 | Train MAE: 0.1266 | Train R2: 0.4956 | Val MSE: 0.0339 | Val MAE: 0.1384 | Val R2: 0.2926
# EarlyStopping counter: 99 out of 250
# Epoch 240/10000 | Train MSE: 0.0270 | Train MAE: 0.1252 | Train R2: 0.5061 | Val MSE: 0.0342 | Val MAE: 0.1389 | Val R2: 0.2873
# EarlyStopping counter: 100 out of 250
# Epoch 241/10000 | Train MSE: 0.0269 | Train MAE: 0.1259 | Train R2: 0.5086 | Val MSE: 0.0342 | Val MAE: 0.1387 | Val R2: 0.2873
# EarlyStopping counter: 101 out of 250
# Epoch 242/10000 | Train MSE: 0.0268 | Train MAE: 0.1259 | Train R2: 0.5106 | Val MSE: 0.0340 | Val MAE: 0.1382 | Val R2: 0.2896
# EarlyStopping counter: 102 out of 250
# Epoch 243/10000 | Train MSE: 0.0268 | Train MAE: 0.1249 | Train R2: 0.5094 | Val MSE: 0.0339 | Val MAE: 0.1376 | Val R2: 0.2921
# EarlyStopping counter: 103 out of 250
# Epoch 244/10000 | Train MSE: 0.0271 | Train MAE: 0.1264 | Train R2: 0.5042 | Val MSE: 0.0340 | Val MAE: 0.1379 | Val R2: 0.2904
# EarlyStopping counter: 104 out of 250
# Epoch 245/10000 | Train MSE: 0.0271 | Train MAE: 0.1247 | Train R2: 0.5049 | Val MSE: 0.0342 | Val MAE: 0.1384 | Val R2: 0.2869
# EarlyStopping counter: 105 out of 250
# Epoch 246/10000 | Train MSE: 0.0269 | Train MAE: 0.1253 | Train R2: 0.5085 | Val MSE: 0.0343 | Val MAE: 0.1390 | Val R2: 0.2836
# EarlyStopping counter: 106 out of 250
# Epoch 247/10000 | Train MSE: 0.0275 | Train MAE: 0.1277 | Train R2: 0.4975 | Val MSE: 0.0343 | Val MAE: 0.1390 | Val R2: 0.2852
# EarlyStopping counter: 107 out of 250
# Epoch 248/10000 | Train MSE: 0.0274 | Train MAE: 0.1266 | Train R2: 0.4981 | Val MSE: 0.0340 | Val MAE: 0.1385 | Val R2: 0.2900
# EarlyStopping counter: 108 out of 250
# Epoch 249/10000 | Train MSE: 0.0270 | Train MAE: 0.1268 | Train R2: 0.5060 | Val MSE: 0.0337 | Val MAE: 0.1375 | Val R2: 0.2970
# EarlyStopping counter: 109 out of 250
# Epoch 250/10000 | Train MSE: 0.0269 | Train MAE: 0.1254 | Train R2: 0.5084 | Val MSE: 0.0337 | Val MAE: 0.1374 | Val R2: 0.2969
# EarlyStopping counter: 110 out of 250
# Epoch 251/10000 | Train MSE: 0.0267 | Train MAE: 0.1252 | Train R2: 0.5121 | Val MSE: 0.0338 | Val MAE: 0.1377 | Val R2: 0.2939
# EarlyStopping counter: 111 out of 250
# Epoch 252/10000 | Train MSE: 0.0267 | Train MAE: 0.1248 | Train R2: 0.5118 | Val MSE: 0.0341 | Val MAE: 0.1384 | Val R2: 0.2874
# EarlyStopping counter: 112 out of 250
# Epoch 253/10000 | Train MSE: 0.0257 | Train MAE: 0.1223 | Train R2: 0.5304 | Val MSE: 0.0345 | Val MAE: 0.1391 | Val R2: 0.2805
# EarlyStopping counter: 113 out of 250
# Epoch 254/10000 | Train MSE: 0.0257 | Train MAE: 0.1234 | Train R2: 0.5300 | Val MSE: 0.0346 | Val MAE: 0.1392 | Val R2: 0.2787
# EarlyStopping counter: 114 out of 250
# Epoch 255/10000 | Train MSE: 0.0266 | Train MAE: 0.1249 | Train R2: 0.5125 | Val MSE: 0.0346 | Val MAE: 0.1391 | Val R2: 0.2773
# EarlyStopping counter: 115 out of 250
# Epoch 256/10000 | Train MSE: 0.0258 | Train MAE: 0.1234 | Train R2: 0.5274 | Val MSE: 0.0346 | Val MAE: 0.1388 | Val R2: 0.2779
# EarlyStopping counter: 116 out of 250
# Epoch 257/10000 | Train MSE: 0.0264 | Train MAE: 0.1242 | Train R2: 0.5172 | Val MSE: 0.0347 | Val MAE: 0.1390 | Val R2: 0.2754
# EarlyStopping counter: 117 out of 250
# Epoch 258/10000 | Train MSE: 0.0259 | Train MAE: 0.1234 | Train R2: 0.5269 | Val MSE: 0.0350 | Val MAE: 0.1398 | Val R2: 0.2702
# EarlyStopping counter: 118 out of 250
# Epoch 259/10000 | Train MSE: 0.0262 | Train MAE: 0.1245 | Train R2: 0.5216 | Val MSE: 0.0351 | Val MAE: 0.1403 | Val R2: 0.2666
# EarlyStopping counter: 119 out of 250
# Epoch 260/10000 | Train MSE: 0.0266 | Train MAE: 0.1253 | Train R2: 0.5137 | Val MSE: 0.0349 | Val MAE: 0.1396 | Val R2: 0.2719
# EarlyStopping counter: 120 out of 250
# Epoch 261/10000 | Train MSE: 0.0260 | Train MAE: 0.1242 | Train R2: 0.5241 | Val MSE: 0.0348 | Val MAE: 0.1392 | Val R2: 0.2739
# EarlyStopping counter: 121 out of 250
# Epoch 262/10000 | Train MSE: 0.0256 | Train MAE: 0.1223 | Train R2: 0.5320 | Val MSE: 0.0349 | Val MAE: 0.1391 | Val R2: 0.2727
# EarlyStopping counter: 122 out of 250
# Epoch 263/10000 | Train MSE: 0.0265 | Train MAE: 0.1241 | Train R2: 0.5148 | Val MSE: 0.0351 | Val MAE: 0.1394 | Val R2: 0.2685
# EarlyStopping counter: 123 out of 250
# Epoch 264/10000 | Train MSE: 0.0247 | Train MAE: 0.1204 | Train R2: 0.5478 | Val MSE: 0.0354 | Val MAE: 0.1402 | Val R2: 0.2610
# EarlyStopping counter: 124 out of 250
# Epoch 265/10000 | Train MSE: 0.0263 | Train MAE: 0.1238 | Train R2: 0.5196 | Val MSE: 0.0353 | Val MAE: 0.1400 | Val R2: 0.2629
# EarlyStopping counter: 125 out of 250
# Epoch 266/10000 | Train MSE: 0.0261 | Train MAE: 0.1234 | Train R2: 0.5227 | Val MSE: 0.0348 | Val MAE: 0.1388 | Val R2: 0.2747
# EarlyStopping counter: 126 out of 250
# Epoch 267/10000 | Train MSE: 0.0246 | Train MAE: 0.1197 | Train R2: 0.5496 | Val MSE: 0.0345 | Val MAE: 0.1381 | Val R2: 0.2807
# EarlyStopping counter: 127 out of 250
# Epoch 268/10000 | Train MSE: 0.0252 | Train MAE: 0.1211 | Train R2: 0.5395 | Val MSE: 0.0345 | Val MAE: 0.1382 | Val R2: 0.2807
# EarlyStopping counter: 128 out of 250
# Epoch 269/10000 | Train MSE: 0.0252 | Train MAE: 0.1220 | Train R2: 0.5398 | Val MSE: 0.0349 | Val MAE: 0.1392 | Val R2: 0.2721
# EarlyStopping counter: 129 out of 250
# Epoch 270/10000 | Train MSE: 0.0251 | Train MAE: 0.1202 | Train R2: 0.5411 | Val MSE: 0.0353 | Val MAE: 0.1399 | Val R2: 0.2642
# EarlyStopping counter: 130 out of 250
# Epoch 271/10000 | Train MSE: 0.0247 | Train MAE: 0.1215 | Train R2: 0.5487 | Val MSE: 0.0357 | Val MAE: 0.1408 | Val R2: 0.2559
# EarlyStopping counter: 131 out of 250
# Epoch 272/10000 | Train MSE: 0.0246 | Train MAE: 0.1199 | Train R2: 0.5495 | Val MSE: 0.0357 | Val MAE: 0.1409 | Val R2: 0.2543
# EarlyStopping counter: 132 out of 250
# Epoch 273/10000 | Train MSE: 0.0239 | Train MAE: 0.1196 | Train R2: 0.5628 | Val MSE: 0.0358 | Val MAE: 0.1406 | Val R2: 0.2536
# EarlyStopping counter: 133 out of 250
# Epoch 274/10000 | Train MSE: 0.0243 | Train MAE: 0.1207 | Train R2: 0.5559 | Val MSE: 0.0359 | Val MAE: 0.1410 | Val R2: 0.2498
# EarlyStopping counter: 134 out of 250
# Epoch 275/10000 | Train MSE: 0.0238 | Train MAE: 0.1198 | Train R2: 0.5641 | Val MSE: 0.0362 | Val MAE: 0.1418 | Val R2: 0.2439
# EarlyStopping counter: 135 out of 250
# ...
# EarlyStopping counter: 154 out of 250
# Epoch 295/10000 | Train MSE: 0.0223 | Train MAE: 0.1153 | Train R2: 0.5922 | Val MSE: 0.0366 | Val MAE: 0.1410 | Val R2: 0.2366
# EarlyStopping counter: 155 out of 250
# Epoch 296/10000 | Train MSE: 0.0233 | Train MAE: 0.1153 | Train R2: 0.5744 | Val MSE: 0.0367 | Val MAE: 0.1412 | Val R2: 0.2343
# EarlyStopping counter: 156 out of 250
# Epoch 297/10000 | Train MSE: 0.0230 | Train MAE: 0.1168 | Train R2: 0.5796 | Val MSE: 0.0368 | Val MAE: 0.1412 | Val R2: 0.2327
# EarlyStopping counter: 157 out of 250
# Epoch 298/10000 | Train MSE: 0.0210 | Train MAE: 0.1114 | Train R2: 0.6155 | Val MSE: 0.0368 | Val MAE: 0.1410 | Val R2: 0.2327
# EarlyStopping counter: 158 out of 250
# Epoch 299/10000 | Train MSE: 0.0218 | Train MAE: 0.1138 | Train R2: 0.6015 | Val MSE: 0.0371 | Val MAE: 0.1416 | Val R2: 0.2258
# EarlyStopping counter: 159 out of 250
# Epoch 300/10000 | Train MSE: 0.0214 | Train MAE: 0.1130 | Train R2: 0.6080 | Val MSE: 0.0377 | Val MAE: 0.1426 | Val R2: 0.2139
# EarlyStopping counter: 160 out of 250
# Epoch 301/10000 | Train MSE: 0.0229 | Train MAE: 0.1160 | Train R2: 0.5810 | Val MSE: 0.0380 | Val MAE: 0.1432 | Val R2: 0.2068
# EarlyStopping counter: 161 out of 250
# Epoch 302/10000 | Train MSE: 0.0226 | Train MAE: 0.1160 | Train R2: 0.5870 | Val MSE: 0.0379 | Val MAE: 0.1427 | Val R2: 0.2096
# EarlyStopping counter: 162 out of 250
# Epoch 303/10000 | Train MSE: 0.0216 | Train MAE: 0.1126 | Train R2: 0.6050 | Val MSE: 0.0382 | Val MAE: 0.1433 | Val R2: 0.2037
# EarlyStopping counter: 163 out of 250
# Epoch 304/10000 | Train MSE: 0.0217 | Train MAE: 0.1146 | Train R2: 0.6029 | Val MSE: 0.0384 | Val MAE: 0.1437 | Val R2: 0.1995
# EarlyStopping counter: 164 out of 250
# Epoch 305/10000 | Train MSE: 0.0216 | Train MAE: 0.1135 | Train R2: 0.6042 | Val MSE: 0.0384 | Val MAE: 0.1437 | Val R2: 0.1985
# EarlyStopping counter: 165 out of 250
# Epoch 306/10000 | Train MSE: 0.0216 | Train MAE: 0.1146 | Train R2: 0.6044 | Val MSE: 0.0382 | Val MAE: 0.1434 | Val R2: 0.2020
# EarlyStopping counter: 166 out of 250
# Epoch 307/10000 | Train MSE: 0.0205 | Train MAE: 0.1102 | Train R2: 0.6249 | Val MSE: 0.0378 | Val MAE: 0.1426 | Val R2: 0.2103
# EarlyStopping counter: 167 out of 250
# Epoch 308/10000 | Train MSE: 0.0216 | Train MAE: 0.1137 | Train R2: 0.6051 | Val MSE: 0.0379 | Val MAE: 0.1428 | Val R2: 0.2096
# EarlyStopping counter: 168 out of 250
# Epoch 309/10000 | Train MSE: 0.0211 | Train MAE: 0.1118 | Train R2: 0.6145 | Val MSE: 0.0379 | Val MAE: 0.1430 | Val R2: 0.2094
# EarlyStopping counter: 169 out of 250
# Epoch 310/10000 | Train MSE: 0.0222 | Train MAE: 0.1150 | Train R2: 0.5939 | Val MSE: 0.0381 | Val MAE: 0.1437 | Val R2: 0.2046
# EarlyStopping counter: 170 out of 250
# Epoch 311/10000 | Train MSE: 0.0211 | Train MAE: 0.1128 | Train R2: 0.6148 | Val MSE: 0.0383 | Val MAE: 0.1442 | Val R2: 0.2013
# EarlyStopping counter: 171 out of 250
# Epoch 312/10000 | Train MSE: 0.0210 | Train MAE: 0.1126 | Train R2: 0.6164 | Val MSE: 0.0384 | Val MAE: 0.1446 | Val R2: 0.1990
# EarlyStopping counter: 172 out of 250
# Epoch 313/10000 | Train MSE: 0.0219 | Train MAE: 0.1150 | Train R2: 0.5995 | Val MSE: 0.0388 | Val MAE: 0.1454 | Val R2: 0.1913
# EarlyStopping counter: 173 out of 250
# Epoch 314/10000 | Train MSE: 0.0209 | Train MAE: 0.1119 | Train R2: 0.6183 | Val MSE: 0.0388 | Val MAE: 0.1453 | Val R2: 0.1903
# EarlyStopping counter: 174 out of 250
# Epoch 315/10000 | Train MSE: 0.0211 | Train MAE: 0.1129 | Train R2: 0.6141 | Val MSE: 0.0389 | Val MAE: 0.1456 | Val R2: 0.1881
# EarlyStopping counter: 175 out of 250
# Epoch 316/10000 | Train MSE: 0.0215 | Train MAE: 0.1120 | Train R2: 0.6072 | Val MSE: 0.0391 | Val MAE: 0.1459 | Val R2: 0.1849
# EarlyStopping counter: 176 out of 250
# Epoch 317/10000 | Train MSE: 0.0199 | Train MAE: 0.1098 | Train R2: 0.6367 | Val MSE: 0.0398 | Val MAE: 0.1474 | Val R2: 0.1693
# EarlyStopping counter: 177 out of 250
# Epoch 318/10000 | Train MSE: 0.0204 | Train MAE: 0.1103 | Train R2: 0.6268 | Val MSE: 0.0398 | Val MAE: 0.1472 | Val R2: 0.1704
# EarlyStopping counter: 178 out of 250
# Epoch 319/10000 | Train MSE: 0.0213 | Train MAE: 0.1135 | Train R2: 0.6102 | Val MSE: 0.0383 | Val MAE: 0.1438 | Val R2: 0.2002
# EarlyStopping counter: 179 out of 250
# Epoch 320/10000 | Train MSE: 0.0206 | Train MAE: 0.1112 | Train R2: 0.6237 | Val MSE: 0.0379 | Val MAE: 0.1425 | Val R2: 0.2083
# EarlyStopping counter: 180 out of 250
# Epoch 321/10000 | Train MSE: 0.0207 | Train MAE: 0.1124 | Train R2: 0.6208 | Val MSE: 0.0383 | Val MAE: 0.1431 | Val R2: 0.2004
# EarlyStopping counter: 181 out of 250
# Epoch 322/10000 | Train MSE: 0.0217 | Train MAE: 0.1132 | Train R2: 0.6026 | Val MSE: 0.0397 | Val MAE: 0.1458 | Val R2: 0.1715
# EarlyStopping counter: 182 out of 250
# Epoch 323/10000 | Train MSE: 0.0201 | Train MAE: 0.1101 | Train R2: 0.6329 | Val MSE: 0.0402 | Val MAE: 0.1464 | Val R2: 0.1618
# EarlyStopping counter: 183 out of 250
# Epoch 324/10000 | Train MSE: 0.0201 | Train MAE: 0.1105 | Train R2: 0.6323 | Val MSE: 0.0393 | Val MAE: 0.1446 | Val R2: 0.1798
# EarlyStopping counter: 184 out of 250
# Epoch 325/10000 | Train MSE: 0.0194 | Train MAE: 0.1076 | Train R2: 0.6454 | Val MSE: 0.0389 | Val MAE: 0.1437 | Val R2: 0.1877
# EarlyStopping counter: 185 out of 250
# Epoch 326/10000 | Train MSE: 0.0209 | Train MAE: 0.1131 | Train R2: 0.6184 | Val MSE: 0.0396 | Val MAE: 0.1452 | Val R2: 0.1739
# EarlyStopping counter: 186 out of 250
# Epoch 327/10000 | Train MSE: 0.0200 | Train MAE: 0.1096 | Train R2: 0.6348 | Val MSE: 0.0407 | Val MAE: 0.1475 | Val R2: 0.1506
# EarlyStopping counter: 187 out of 250
# Epoch 328/10000 | Train MSE: 0.0194 | Train MAE: 0.1084 | Train R2: 0.6453 | Val MSE: 0.0411 | Val MAE: 0.1486 | Val R2: 0.1430
# EarlyStopping counter: 188 out of 250
# Epoch 329/10000 | Train MSE: 0.0201 | Train MAE: 0.1105 | Train R2: 0.6325 | Val MSE: 0.0397 | Val MAE: 0.1461 | Val R2: 0.1721
# EarlyStopping counter: 189 out of 250
# Epoch 330/10000 | Train MSE: 0.0191 | Train MAE: 0.1090 | Train R2: 0.6500 | Val MSE: 0.0389 | Val MAE: 0.1445 | Val R2: 0.1885
# EarlyStopping counter: 190 out of 250
# Epoch 331/10000 | Train MSE: 0.0199 | Train MAE: 0.1104 | Train R2: 0.6361 | Val MSE: 0.0387 | Val MAE: 0.1440 | Val R2: 0.1934
# EarlyStopping counter: 191 out of 250
# Epoch 332/10000 | Train MSE: 0.0191 | Train MAE: 0.1070 | Train R2: 0.6515 | Val MSE: 0.0395 | Val MAE: 0.1457 | Val R2: 0.1759
# EarlyStopping counter: 192 out of 250
# Epoch 333/10000 | Train MSE: 0.0192 | Train MAE: 0.1053 | Train R2: 0.6490 | Val MSE: 0.0408 | Val MAE: 0.1481 | Val R2: 0.1478
# EarlyStopping counter: 193 out of 250
# Epoch 334/10000 | Train MSE: 0.0204 | Train MAE: 0.1100 | Train R2: 0.6268 | Val MSE: 0.0401 | Val MAE: 0.1465 | Val R2: 0.1628
# EarlyStopping counter: 194 out of 250
# Epoch 335/10000 | Train MSE: 0.0191 | Train MAE: 0.1055 | Train R2: 0.6505 | Val MSE: 0.0395 | Val MAE: 0.1452 | Val R2: 0.1754
# EarlyStopping counter: 195 out of 250
# Epoch 336/10000 | Train MSE: 0.0199 | Train MAE: 0.1094 | Train R2: 0.6357 | Val MSE: 0.0395 | Val MAE: 0.1450 | Val R2: 0.1762
# EarlyStopping counter: 196 out of 250
# Epoch 337/10000 | Train MSE: 0.0189 | Train MAE: 0.1082 | Train R2: 0.6537 | Val MSE: 0.0400 | Val MAE: 0.1459 | Val R2: 0.1648
# EarlyStopping counter: 197 out of 250
# Epoch 338/10000 | Train MSE: 0.0188 | Train MAE: 0.1070 | Train R2: 0.6562 | Val MSE: 0.0402 | Val MAE: 0.1462 | Val R2: 0.1604
# EarlyStopping counter: 198 out of 250
# Epoch 339/10000 | Train MSE: 0.0187 | Train MAE: 0.1057 | Train R2: 0.6581 | Val MSE: 0.0402 | Val MAE: 0.1462 | Val R2: 0.1607
# EarlyStopping counter: 199 out of 250
# Epoch 340/10000 | Train MSE: 0.0194 | Train MAE: 0.1076 | Train R2: 0.6448 | Val MSE: 0.0401 | Val MAE: 0.1458 | Val R2: 0.1640
# EarlyStopping counter: 200 out of 250
# Epoch 341/10000 | Train MSE: 0.0187 | Train MAE: 0.1062 | Train R2: 0.6570 | Val MSE: 0.0402 | Val MAE: 0.1461 | Val R2: 0.1615
# EarlyStopping counter: 201 out of 250
# Epoch 342/10000 | Train MSE: 0.0187 | Train MAE: 0.1069 | Train R2: 0.6579 | Val MSE: 0.0407 | Val MAE: 0.1471 | Val R2: 0.1499
# EarlyStopping counter: 202 out of 250
# Epoch 343/10000 | Train MSE: 0.0182 | Train MAE: 0.1046 | Train R2: 0.6677 | Val MSE: 0.0417 | Val MAE: 0.1492 | Val R2: 0.1290
# EarlyStopping counter: 203 out of 250
# Epoch 344/10000 | Train MSE: 0.0197 | Train MAE: 0.1078 | Train R2: 0.6401 | Val MSE: 0.0414 | Val MAE: 0.1488 | Val R2: 0.1357
# EarlyStopping counter: 204 out of 250
# Epoch 345/10000 | Train MSE: 0.0194 | Train MAE: 0.1071 | Train R2: 0.6451 | Val MSE: 0.0412 | Val MAE: 0.1487 | Val R2: 0.1409
# EarlyStopping counter: 205 out of 250
# Epoch 346/10000 | Train MSE: 0.0172 | Train MAE: 0.1000 | Train R2: 0.6847 | Val MSE: 0.0409 | Val MAE: 0.1484 | Val R2: 0.1469
# EarlyStopping counter: 206 out of 250
# Epoch 347/10000 | Train MSE: 0.0191 | Train MAE: 0.1077 | Train R2: 0.6507 | Val MSE: 0.0407 | Val MAE: 0.1483 | Val R2: 0.1501
# EarlyStopping counter: 207 out of 250
# Epoch 348/10000 | Train MSE: 0.0185 | Train MAE: 0.1058 | Train R2: 0.6611 | Val MSE: 0.0407 | Val MAE: 0.1484 | Val R2: 0.1499
# EarlyStopping counter: 208 out of 250
# Epoch 349/10000 | Train MSE: 0.0181 | Train MAE: 0.1052 | Train R2: 0.6689 | Val MSE: 0.0408 | Val MAE: 0.1486 | Val R2: 0.1477
# EarlyStopping counter: 209 out of 250
# Epoch 350/10000 | Train MSE: 0.0175 | Train MAE: 0.1034 | Train R2: 0.6795 | Val MSE: 0.0408 | Val MAE: 0.1484 | Val R2: 0.1478
# EarlyStopping counter: 210 out of 250
# Epoch 351/10000 | Train MSE: 0.0187 | Train MAE: 0.1053 | Train R2: 0.6586 | Val MSE: 0.0405 | Val MAE: 0.1478 | Val R2: 0.1541
# EarlyStopping counter: 211 out of 250
# Epoch 352/10000 | Train MSE: 0.0187 | Train MAE: 0.1071 | Train R2: 0.6581 | Val MSE: 0.0408 | Val MAE: 0.1483 | Val R2: 0.1477
# EarlyStopping counter: 212 out of 250
# Epoch 353/10000 | Train MSE: 0.0177 | Train MAE: 0.1031 | Train R2: 0.6763 | Val MSE: 0.0416 | Val MAE: 0.1496 | Val R2: 0.1311
# EarlyStopping counter: 213 out of 250
# Epoch 354/10000 | Train MSE: 0.0176 | Train MAE: 0.1031 | Train R2: 0.6784 | Val MSE: 0.0415 | Val MAE: 0.1492 | Val R2: 0.1343
# EarlyStopping counter: 214 out of 250
# Epoch 355/10000 | Train MSE: 0.0171 | Train MAE: 0.1021 | Train R2: 0.6879 | Val MSE: 0.0412 | Val MAE: 0.1487 | Val R2: 0.1397
# EarlyStopping counter: 215 out of 250
# Epoch 356/10000 | Train MSE: 0.0170 | Train MAE: 0.1016 | Train R2: 0.6895 | Val MSE: 0.0418 | Val MAE: 0.1498 | Val R2: 0.1270
# EarlyStopping counter: 216 out of 250
# Epoch 357/10000 | Train MSE: 0.0176 | Train MAE: 0.1049 | Train R2: 0.6779 | Val MSE: 0.0429 | Val MAE: 0.1517 | Val R2: 0.1044
# EarlyStopping counter: 217 out of 250
# Epoch 358/10000 | Train MSE: 0.0192 | Train MAE: 0.1082 | Train R2: 0.6487 | Val MSE: 0.0419 | Val MAE: 0.1499 | Val R2: 0.1255
# EarlyStopping counter: 218 out of 250
# Epoch 359/10000 | Train MSE: 0.0172 | Train MAE: 0.1022 | Train R2: 0.6853 | Val MSE: 0.0411 | Val MAE: 0.1485 | Val R2: 0.1414
# EarlyStopping counter: 219 out of 250
# Epoch 360/10000 | Train MSE: 0.0166 | Train MAE: 0.0996 | Train R2: 0.6970 | Val MSE: 0.0408 | Val MAE: 0.1477 | Val R2: 0.1489
# EarlyStopping counter: 220 out of 250
# Epoch 361/10000 | Train MSE: 0.0173 | Train MAE: 0.1025 | Train R2: 0.6826 | Val MSE: 0.0414 | Val MAE: 0.1488 | Val R2: 0.1360
# EarlyStopping counter: 221 out of 250
# Epoch 362/10000 | Train MSE: 0.0169 | Train MAE: 0.1006 | Train R2: 0.6915 | Val MSE: 0.0419 | Val MAE: 0.1499 | Val R2: 0.1254
# EarlyStopping counter: 222 out of 250
# Epoch 363/10000 | Train MSE: 0.0175 | Train MAE: 0.1040 | Train R2: 0.6790 | Val MSE: 0.0411 | Val MAE: 0.1483 | Val R2: 0.1427
# EarlyStopping counter: 223 out of 250
# Epoch 364/10000 | Train MSE: 0.0160 | Train MAE: 0.0974 | Train R2: 0.7079 | Val MSE: 0.0403 | Val MAE: 0.1470 | Val R2: 0.1588
# EarlyStopping counter: 224 out of 250
# Epoch 365/10000 | Train MSE: 0.0170 | Train MAE: 0.1002 | Train R2: 0.6882 | Val MSE: 0.0406 | Val MAE: 0.1475 | Val R2: 0.1526
# EarlyStopping counter: 225 out of 250
# Epoch 366/10000 | Train MSE: 0.0173 | Train MAE: 0.1019 | Train R2: 0.6832 | Val MSE: 0.0422 | Val MAE: 0.1502 | Val R2: 0.1191
# EarlyStopping counter: 226 out of 250
# Epoch 367/10000 | Train MSE: 0.0176 | Train MAE: 0.1039 | Train R2: 0.6786 | Val MSE: 0.0427 | Val MAE: 0.1507 | Val R2: 0.1097
# EarlyStopping counter: 227 out of 250
# Epoch 368/10000 | Train MSE: 0.0159 | Train MAE: 0.0987 | Train R2: 0.7094 | Val MSE: 0.0416 | Val MAE: 0.1489 | Val R2: 0.1312
# EarlyStopping counter: 228 out of 250
# Epoch 369/10000 | Train MSE: 0.0184 | Train MAE: 0.1057 | Train R2: 0.6633 | Val MSE: 0.0415 | Val MAE: 0.1486 | Val R2: 0.1334
# EarlyStopping counter: 229 out of 250
# Epoch 370/10000 | Train MSE: 0.0168 | Train MAE: 0.1015 | Train R2: 0.6919 | Val MSE: 0.0421 | Val MAE: 0.1493 | Val R2: 0.1213
# EarlyStopping counter: 230 out of 250
# Epoch 371/10000 | Train MSE: 0.0168 | Train MAE: 0.1014 | Train R2: 0.6931 | Val MSE: 0.0438 | Val MAE: 0.1525 | Val R2: 0.0857
# EarlyStopping counter: 231 out of 250
# Epoch 372/10000 | Train MSE: 0.0175 | Train MAE: 0.1043 | Train R2: 0.6796 | Val MSE: 0.0436 | Val MAE: 0.1520 | Val R2: 0.0906
# EarlyStopping counter: 232 out of 250
# Epoch 373/10000 | Train MSE: 0.0172 | Train MAE: 0.1015 | Train R2: 0.6845 | Val MSE: 0.0417 | Val MAE: 0.1487 | Val R2: 0.1300
# EarlyStopping counter: 233 out of 250
# Epoch 374/10000 | Train MSE: 0.0162 | Train MAE: 0.0987 | Train R2: 0.7032 | Val MSE: 0.0411 | Val MAE: 0.1482 | Val R2: 0.1415
# EarlyStopping counter: 234 out of 250
# Epoch 375/10000 | Train MSE: 0.0157 | Train MAE: 0.0964 | Train R2: 0.7136 | Val MSE: 0.0421 | Val MAE: 0.1498 | Val R2: 0.1205
# EarlyStopping counter: 235 out of 250
# Epoch 376/10000 | Train MSE: 0.0175 | Train MAE: 0.1030 | Train R2: 0.6797 | Val MSE: 0.0423 | Val MAE: 0.1503 | Val R2: 0.1166
# EarlyStopping counter: 236 out of 250
# Epoch 377/10000 | Train MSE: 0.0158 | Train MAE: 0.0982 | Train R2: 0.7116 | Val MSE: 0.0410 | Val MAE: 0.1485 | Val R2: 0.1439
# EarlyStopping counter: 237 out of 250
# Epoch 378/10000 | Train MSE: 0.0170 | Train MAE: 0.1025 | Train R2: 0.6895 | Val MSE: 0.0398 | Val MAE: 0.1467 | Val R2: 0.1685
# EarlyStopping counter: 238 out of 250
# Epoch 379/10000 | Train MSE: 0.0163 | Train MAE: 0.0997 | Train R2: 0.7018 | Val MSE: 0.0400 | Val MAE: 0.1468 | Val R2: 0.1650
# EarlyStopping counter: 239 out of 250
# Epoch 380/10000 | Train MSE: 0.0171 | Train MAE: 0.1016 | Train R2: 0.6869 | Val MSE: 0.0417 | Val MAE: 0.1492 | Val R2: 0.1308
# EarlyStopping counter: 240 out of 250
# Epoch 381/10000 | Train MSE: 0.0159 | Train MAE: 0.0978 | Train R2: 0.7094 | Val MSE: 0.0426 | Val MAE: 0.1507 | Val R2: 0.1102
# EarlyStopping counter: 241 out of 250
# Epoch 382/10000 | Train MSE: 0.0161 | Train MAE: 0.0982 | Train R2: 0.7060 | Val MSE: 0.0428 | Val MAE: 0.1510 | Val R2: 0.1078
# EarlyStopping counter: 242 out of 250
# Epoch 383/10000 | Train MSE: 0.0162 | Train MAE: 0.0990 | Train R2: 0.7033 | Val MSE: 0.0427 | Val MAE: 0.1511 | Val R2: 0.1098
# EarlyStopping counter: 243 out of 250
# Epoch 384/10000 | Train MSE: 0.0161 | Train MAE: 0.0993 | Train R2: 0.7046 | Val MSE: 0.0429 | Val MAE: 0.1517 | Val R2: 0.1046
# EarlyStopping counter: 244 out of 250
# Epoch 385/10000 | Train MSE: 0.0165 | Train MAE: 0.1003 | Train R2: 0.6984 | Val MSE: 0.0441 | Val MAE: 0.1535 | Val R2: 0.0789
# EarlyStopping counter: 245 out of 250
# Epoch 386/10000 | Train MSE: 0.0165 | Train MAE: 0.0988 | Train R2: 0.6981 | Val MSE: 0.0444 | Val MAE: 0.1539 | Val R2: 0.0741
# EarlyStopping counter: 246 out of 250
# Epoch 387/10000 | Train MSE: 0.0153 | Train MAE: 0.0969 | Train R2: 0.7201 | Val MSE: 0.0431 | Val MAE: 0.1521 | Val R2: 0.1002
# EarlyStopping counter: 247 out of 250
# Epoch 388/10000 | Train MSE: 0.0162 | Train MAE: 0.0994 | Train R2: 0.7028 | Val MSE: 0.0414 | Val MAE: 0.1495 | Val R2: 0.1368
# EarlyStopping counter: 248 out of 250
# Epoch 389/10000 | Train MSE: 0.0149 | Train MAE: 0.0953 | Train R2: 0.7282 | Val MSE: 0.0405 | Val MAE: 0.1480 | Val R2: 0.1539
# EarlyStopping counter: 249 out of 250
# Epoch 390/10000 | Train MSE: 0.0164 | Train MAE: 0.0991 | Train R2: 0.7008 | Val MSE: 0.0413 | Val MAE: 0.1491 | Val R2: 0.1384
# EarlyStopping counter: 250 out of 250
# 早停机制触发，停止训练。

# %% [markdown]
# # 记录训练时间

# %%
training_time = time.time() - start_time
print("训练时间: {:.5f} 秒".format(training_time))
# Out:
# 训练时间: 533.18878 秒

# %%
# Custom interval prediction logic
if args.predict_start is not None or args.predict_end is not None:
    # Check if both start and end indices are provided
    if args.predict_start is None or args.predict_end is None:
        raise ValueError("Both --predict_start and --predict_end parameters must be provided")
    
    # Validate index validity
    if args.predict_start < args.window_size:
        raise ValueError(f"predict_start must be greater than or equal to the window size {args.window_size}")
    if args.predict_end >= len(features_scaled):
        raise ValueError(f"predict_end must be less than the data length {len(features_scaled)}")
    if args.predict_start > args.predict_end:
        raise ValueError("predict_start must be less than or equal to predict_end")

    # Generate input window data
    x_custom = []
    for i in range(args.predict_start, args.predict_end + 1):
        start_idx = i - args.window_size
        end_idx = i
        window_data = features_scaled[start_idx:end_idx, :]  # (window_size, n_features)
        x_custom.append(window_data)
    x_custom = np.array(x_custom)  # (n_samples, window_size, n_features)
    
    # Convert to tensor
    x_custom_tensor = torch.from_numpy(x_custom).float().to(args.device)
    
    # Perform prediction
    model.eval()
    with torch.no_grad():
        y_custom_pred = model(x_custom_tensor)
    
    # Inverse transform prediction results
    y_custom_pred_inv = target_scaler.inverse_transform(y_custom_pred.cpu().numpy())
    
    # Get true values
    y_custom_true = target_scaler.inverse_transform(target_scaled[args.predict_start:args.predict_end + 1])
    
    # Evaluation metrics
    custom_rmse = math.sqrt(mean_squared_error(y_custom_true, y_custom_pred_inv))
    custom_mae = mean_absolute_error(y_custom_true, y_custom_pred_inv)
    custom_r2 = r2_score(y_custom_true, y_custom_pred_inv)
    
    print(f"\nCustom Prediction Results ({args.predict_start}-{args.predict_end}):")
    print(f"RMSE: {custom_rmse:.5f}")
    print(f"MAE: {custom_mae:.5f}")
    print(f"R²: {custom_r2:.5f}")

    # Visualize results
    output_dir_custom = f'../{args.model_name}/custom'
    os.makedirs(output_dir_custom, exist_ok=True)
    
    for i in range(len(args.output_features)):
        feature_name = param_index_dict[i]
        plt.figure(figsize=(14, 6))
        
        # Generate x-axis labels
        if 'DATE' in data.columns:
            dates = data['DATE'].iloc[args.predict_start:args.predict_end + 1]
            x_axis = dates
        else:
            x_axis = range(args.predict_start, args.predict_end + 1)
        
        plt.plot(x_axis, y_custom_true[:, i], label='Actual Value', color='blue')
        plt.plot(x_axis, y_custom_pred_inv[:, i], label='Predicted Value', color='red', linestyle='--')
        
        plt.title(f'{feature_name} Prediction Comparison (Index {args.predict_start}-{args.predict_end})')
        plt.xlabel('Date' if 'DATE' in data.columns else 'Index')
        plt.ylabel('Value')
        plt.legend()
        plt.grid(True)
        
        # Save the plot
        timestamp = time.strftime("%Y%m%d_%H%M%S")
        plt.savefig(os.path.join(output_dir_custom, 
                    f'custom_{feature_name}_{args.predict_start}_to_{args.predict_end}_{timestamp}.png'))
        plt.close()

# Load the best model (if early stopping is enabled)
if args.use_early_stopping:
    model.load_state_dict(torch.load(checkpoint_path))

# Inverse transform prediction and true values
y_train_pred_inv = target_scaler.inverse_transform(y_train_pred.detach().cpu().numpy())
y_train_true = target_scaler.inverse_transform(y_train.detach().cpu().numpy())
y_val_pred_inv = target_scaler.inverse_transform(y_val_pred.detach().cpu().numpy())
y_val_true = target_scaler.inverse_transform(y_val.detach().cpu().numpy())
y_test_pred = model(x_test)
y_test_pred_inv = target_scaler.inverse_transform(y_test_pred.detach().cpu().numpy())
y_test_full = target_scaler.inverse_transform(y_test.detach().cpu().numpy())

# Training set evaluation
train_rmse = math.sqrt(mean_squared_error(y_train_true, y_train_pred_inv))
train_mae = mean_absolute_error(y_train_true, y_train_pred_inv)
train_mse = mean_squared_error(y_train_true, y_train_pred_inv)
r2_train = r2_score(y_train_true, y_train_pred_inv)
print('Train Score: {:.5f} RMSE'.format(train_rmse))
print('Train MAE: {:.5f}'.format(train_mae))
print('Train MSE: {:.5f}'.format(train_mse))
print('Train R^2: {:.5f}'.format(r2_train))

# Validation set evaluation
val_rmse = math.sqrt(mean_squared_error(y_val_true, y_val_pred_inv))
val_mae = mean_absolute_error(y_val_true, y_val_pred_inv)
val_mse = mean_squared_error(y_val_true, y_val_pred_inv)
r2_val = r2_score(y_val_true, y_val_pred_inv)
print('Validation Score: {:.5f} RMSE'.format(val_rmse))
print('Validation MAE: {:.5f}'.format(val_mae))
print('Validation MSE: {:.5f}'.format(val_mse))
print('Validation R^2: {:.5f}'.format(r2_val))

# Test set evaluation
test_rmse = math.sqrt(mean_squared_error(y_test_full, y_test_pred_inv))
test_mae = mean_absolute_error(y_test_full, y_test_pred_inv)
test_mse = mean_squared_error(y_test_full, y_test_pred_inv)
r2_test = r2_score(y_test_full, y_test_pred_inv)
print('Test Score: {:.5f} RMSE'.format(test_rmse))
print('Test MAE: {:.5f}'.format(test_mae))
print('Test MSE: {:.5f}'.format(test_mse))
print('Test R^2: {:.5f}'.format(r2_test))

# Save model evaluation results
file_path = 'model_scores.csv'
# Create a DataFrame containing the current model results
data_scores = {
    "Model Name": [args.model_name],
    "Train RMSE": [train_rmse],
    "Train MAE": [train_mae],
    "Train MSE": [train_mse],
    "Train R^2": [r2_train],
    "Validation RMSE": [val_rmse],
    "Validation MAE": [val_mae],
    "Validation MSE": [val_mse],
    "Validation R^2": [r2_val],
    "Test RMSE": [test_rmse],
    "Test MAE": [test_mae],
    "Test MSE": [test_mse],
    "Test R^2": [r2_test],
    "Training Time (s)": [training_time],
    # Record hyperparameters
    "Learning Rate": [args.lr],
    "Hidden Dim": [args.hidden_dim],
    "Num Layers": [args.n_layers],
    "Dropout": [args.dropout],
    "Window Size": [args.window_size],
    "Patience": [args.patience],
    "Delta": [args.delta]
}
# Ensure each run's record is unique by adding a timestamp to the model name
current_time_str_filename = time.strftime("%Y%m%d_%H%M%S", time.localtime())
df_scores = pd.DataFrame(data_scores, index=[f"{args.model_name}_{current_time_str_filename}"])
# Check if the file exists
if Path(file_path).exists():
    # File exists, append data
    df_scores.to_csv(file_path, mode='a', header=False, index=True)
else:
    # File does not exist, create the file and write data
    df_scores.to_csv(file_path, index=True)

# Inverse transform predictions for visualization
y_test_pred_full = y_test_pred_inv
y_test_full = y_test_full  # Already inverse transformed

# Create output directories
output_dir_train = f'../{args.model_name}/train'
output_dir_val = f'../{args.model_name}/val'
output_dir_test = f'../{args.model_name}/test'
os.makedirs(output_dir_train, exist_ok=True)
os.makedirs(output_dir_val, exist_ok=True)
os.makedirs(output_dir_test, exist_ok=True)

# Get the date or sample index from the original data
if 'DATE' in data.columns:
    dates = pd.to_datetime(data['DATE'])
    x_axis = dates
else:
    x_axis = range(len(data))

# Plot predictions for training, validation, and test sets
for i in range(len(args.output_features)):
    feature_name = param_index_dict[i]
    
    # Get the current time string
    current_time_str_filename = time.strftime("%Y%m%d_%H%M%S", time.localtime())
    
    # Plot training set prediction results
    plt.figure(figsize=(14, 6))
    plt.plot(x_axis[args.window_size:args.window_size + len(y_train_true)], y_train_true[:, i], label='Actual Train', color='blue')
    plt.plot(x_axis[args.window_size:args.window_size + len(y_train_pred_inv)], y_train_pred_inv[:, i], label=f'Train Prediction ({args.model_name})', color='orange')
    plt.title(f'Training Set Prediction vs Actual ({feature_name})', fontsize=16, fontweight='bold')
    plt.xlabel('Date' if 'DATE' in data.columns else 'Index', fontsize=14)
    plt.ylabel('Value', fontsize=14)
    plt.legend()
    plt.grid(True)
    
    # Add timestamp to filename
    plt.savefig(os.path.join(output_dir_train, f'{feature_name}_train_{current_time_str_filename}.png'))
    plt.close()
    
    # Plot validation set prediction results
    plt.figure(figsize=(14, 6))
    plt.plot(x_axis[args.window_size + len(y_train_true):args.window_size + len(y_train_true) + len(y_val_true)], y_val_true[:, i], label='Actual Validation', color='green')
    plt.plot(x_axis[args.window_size + len(y_train_true):args.window_size + len(y_train_true) + len(y_val_pred_inv)], y_val_pred_inv[:, i], label=f'Validation Prediction ({args.model_name})', color='red')
    plt.title(f'Validation Set Prediction vs Actual ({feature_name})', fontsize=16, fontweight='bold')
    plt.xlabel('Date' if 'DATE' in data.columns else 'Index', fontsize=14)
    plt.ylabel('Value', fontsize=14)
    plt.legend()
    plt.grid(True)
    
    # Add timestamp to filename
    plt.savefig(os.path.join(output_dir_val, f'{feature_name}_val_{current_time_str_filename}.png'))
    plt.close()
    
    # Plot test set prediction results
    plt.figure(figsize=(14, 6))
    plt.plot(x_axis[args.window_size + len(y_train_true) + len(y_val_true):args.window_size + len(y_train_true) + len(y_val_true) + len(y_test_full)], y_test_full[:, i], label='Actual Test', color='purple')
    plt.plot(x_axis[args.window_size + len(y_train_true) + len(y_val_true):args.window_size + len(y_train_true) + len(y_val_true) + len(y_test_pred_inv)], y_test_pred_inv[:, i], label=f'Test Prediction ({args.model_name})', color='brown')
    plt.title(f'Test Set Prediction vs Actual ', fontsize=16, fontweight='bold')
    plt.xlabel('Date' if 'DATE' in data.columns else 'Index', fontsize=14)
    plt.ylabel('Value', fontsize=14)
    plt.legend()
    plt.grid(True)
    
    # Add timestamp to filename
    plt.savefig(os.path.join(output_dir_test, f'{feature_name}_test_{current_time_str_filename}.png'))
    plt.close()

print("All prediction result plots have been completed and saved.")
# Out:
# Custom Prediction Results (1000-1655):
# RMSE: 70.45260
# MAE: 52.98128
# R²: 0.56963
# Train Score: 63.68826 RMSE
# Train MAE: 49.33829
# Train MSE: 4056.19409
# Train R^2: 0.70080
# Validation Score: 101.18649 RMSE
# Validation MAE: 74.27546
# Validation MSE: 10238.70508
# Validation R^2: 0.13845
# Test Score: 76.51388 RMSE
# Test MAE: 57.33516
# Test MSE: 5854.37402
# Test R^2: 0.30445
# All prediction result plots have been completed and saved.

# %%
# output_dir = Path(f'../{args.model_name}')
# output_dir.mkdir(parents=True, exist_ok=True)# 在训练循环之后添加结果保存部分
# current_time_str = time.strftime("%Y%m%d_%H%M%S")

# # 保存训练集预测结果
# train_results = pd.DataFrame({
#     'timestamp': data['time'].iloc[args.window_size : args.window_size + len(y_train)],
#     'actual': y_train_true.squeeze(),
#     'predicted': y_train_pred_inv.squeeze()
# })
# train_results.to_csv(output_dir / f'train_results_{current_time_str}.csv', index=False)

# # 保存验证集预测结果
# val_results = pd.DataFrame({
#     'timestamp': data['time'].iloc[args.window_size + len(y_train) : args.window_size + len(y_train) + len(y_val)],
#     'actual': y_val_true.squeeze(),
#     'predicted': y_val_pred_inv.squeeze()
# })
# val_results.to_csv(output_dir / f'val_results_{current_time_str}.csv', index=False)

# # 保存测试集预测结果
# test_results = pd.DataFrame({
#     'timestamp': data['time'].iloc[args.window_size + len(y_train) + len(y_val) : args.window_size + len(y_train) + len(y_val) + len(y_test)],
#     'actual': y_test_full.squeeze(),
#     'predicted': y_test_pred_inv.squeeze()
# })
# test_results.to_csv(output_dir / f'test_results_{current_time_str}.csv', index=False)

# # 保存自定义区间预测结果（如果有）
# if 'y_custom_pred_inv' in locals():
#     custom_results = pd.DataFrame({
#         'timestamp': data['time'].iloc[args.predict_start : args.predict_end + 1],
#         'actual': y_custom_true.squeeze(),
#         'predicted': y_custom_pred_inv.squeeze()
#     })
#     custom_results.to_csv(output_dir / f'custom_{args.predict_start}-{args.predict_end}_results_{current_time_str}.csv', index=False)

# # 保存评估指标
# metrics = pd.DataFrame({
#     'dataset': ['train', 'val', 'test'],
#     'RMSE': [train_rmse, val_rmse, test_rmse],
#     'MAE': [train_mae, val_mae, test_mae],
#     'R2': [r2_train, r2_val, r2_test],
#     'MSE': [train_mse, val_mse, test_mse]
# })
# metrics.to_csv(output_dir / f'metrics_{current_time_str}.csv', index=False)

# # 保存完整配置
# with open(output_dir / f'config_{current_time_str}.txt', 'w') as f:
#     for key, value in vars(args).items():
#         f.write(f"{key}: {value}\n")

# print("所有预测结果和评估指标已保存至:", output_dir)
