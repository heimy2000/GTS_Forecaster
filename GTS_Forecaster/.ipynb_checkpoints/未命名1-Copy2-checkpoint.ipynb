# %% [markdown]
# # GNSS时间序列预测深度学习模型

# %% [markdown]
# ### 本Notebook实现基于深度学习的GNSS时间序列预测，支持LSTM/GRU/TCN/Transformer等模型
# ## 1. 环境准备

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import time
import math
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import plotly.express as px
import plotly.graph_objects as go
from utils import split_data
import argparse
import os
from model import *
from utils import *
from pathlib import Path

plt.rcParams['font.family'] = ['SimHei']  # 替换为你的字体名称
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False  # 解决负号显示问题

# %% [markdown]
# # 解析命令行参数

# %%
parser = argparse.ArgumentParser()
# data
parser.add_argument('--path', type=str, default='../data/cleaned_data_filtered.csv', help="文件路径")
parser.add_argument('--vision', type=bool, default=True)
parser.add_argument('--input_features', type=list, default=['time','value'], help="输入特征")
parser.add_argument('--output_features', type=list, default=['value'], help="输出特征")
parser.add_argument('--window_size', type=int, default=100)
parser.add_argument('--train_test_ratio', type=float, default=0.1)
parser.add_argument('--random_state', type=int, default=34)
# model
parser.add_argument('--model_name', type=str, default='LSTM', help='模型名称选项，LSTM,LSTM_ekan,TCN_ekan,TCN,Transformer,Transformer_ekan,BiLSTM,BiLSTM_ekan,GRU,GRU_ekan,LSTM_Attention，VanillaLSTM，ConvLSTM，CustomLSTM')
parser.add_argument('--dropout', type=float, default=0.1)
parser.add_argument('--hidden_dim', type=int, default=32)
parser.add_argument('--n_layers', type=int, default=2)
##kan
parser.add_argument('--grid_size', type=int, default=200, help='grid')
##TCN
parser.add_argument('--num_channels', type=list, default=[25, 50, 25])
parser.add_argument('--kernel_size', type=int, default=3)
##transformer
parser.add_argument('--num_heads', type=int, default=8)  # 确保这行存在
parser.add_argument('--hidden_space', type=int, default=32)
# training
parser.add_argument('--num_epochs', type=int, default=10000)
parser.add_argument('--seed', type=int, default=1)
# optimizer
parser.add_argument('--lr', type=float, default=0.001, help='学习率')
# 在参数解析部分添加TimeGNN专用参数
#parser.add_argument('--seq_len', type=int, default=24, help='时间序列长度')
parser.add_argument('--aggregate', type=str, default='last', choices=['mean', 'last'])
parser.add_argument('--keep_self_loops', action='store_true')
parser.add_argument('--enforce_consecutive', action='store_true')
parser.add_argument('--block_size', type=int, default=3)
parser.add_argument('--batch_size', type=int, default=32)  # 新增关键行
parser.add_argument('--seq_len', type=int, default=24)      # TimeGNN专用参数

parser.add_argument('--predict_start', type=int, default=400, help='Start index in original data for prediction')
parser.add_argument('--predict_end', type=int, default=1655, help='End index in original data for prediction')

# 早停参数
parser.add_argument('--use_early_stopping', action='store_true', help='启用早停')
parser.add_argument('--patience', type=int, default=250, help='早停耐心值')
parser.add_argument('--delta', type=float, default=0, help='早停最小变化量')
# 预测数量参数
parser.add_argument('--predict_nums', type=int, nargs='+', default=[30, 60, 360], help='预测长度列表，即为预测天数')
#args = parser.parse_args(args=[''])
args = parser.parse_args(args=['--use_early_stopping'])
args.device = torch.device('cpu')

# %% [markdown]
# ## 读取数据

# %%
data = pd.read_csv(args.path)
# 按照时间排序
data = data.sort_values('time')

# %% [markdown]
# # 数据可视化

# %%
if args.vision:
    sns.set_style("darkgrid")
    plt.figure(figsize=(15, 9))
    plt.plot(data['value'], label='value')
    plt.xticks(range(0, data.shape[0], 20), data['time'].iloc[::20], rotation=45)
    plt.title("GNSS Time Series", fontsize=18, fontweight='bold')
    plt.xlabel('value', fontsize=18)
    plt.ylabel('GNSS Value', fontsize=18)
    plt.legend()

# %% [markdown]
# # 特征缩放
# 缩放为计算机可以看懂的语言

# %%
features = data[args.input_features]
scaler = MinMaxScaler(feature_range=(-1, 1))
features_scaled = scaler.fit_transform(features)

target = data[args.output_features]
target_scaler = MinMaxScaler(feature_range=(-1, 1))
target_scaled = target_scaler.fit_transform(target)

one_scaler = MinMaxScaler(feature_range=(-1, 1))
one_scaled = one_scaler.fit_transform(data[['value']])

output_colnames = args.output_features
param = list(output_colnames)
param_index = range(len(param))
param_index_dict = dict(zip(param_index, param))

# %% [markdown]
# # 数据拆分

# %%
x_train, y_train, x_test, y_test = split_data(features_scaled, target_scaled, args.window_size)
print('x_train.shape = ', x_train.shape)
print('y_train.shape = ', y_train.shape)
print('x_test.shape = ', x_test.shape)
print('y_test.shape = ', y_test.shape)
# Out:
# x_train.shape =  (1294, 99, 2)
# y_train.shape =  (1294, 1)
# x_test.shape =  (323, 99, 2)
# y_test.shape =  (323, 1)

# %% [markdown]
# # 进一步划分训练集和验证集 BEFORE 转换为 Torch 张量

# %%
x_train, x_val, y_train, y_val = train_test_split(
    x_train, y_train, test_size=args.train_test_ratio, random_state=args.random_state
)
print('x_train.shape = ', x_train.shape)
print('y_train.shape = ', y_train.shape)
print('x_val.shape = ', x_val.shape)
print('y_val.shape = ', y_val.shape)
print('x_test.shape = ', x_test.shape)
print('y_test.shape = ', y_test.shape)
# Out:
# x_train.shape =  (1164, 99, 2)
# y_train.shape =  (1164, 1)
# x_val.shape =  (130, 99, 2)
# y_val.shape =  (130, 1)
# x_test.shape =  (323, 99, 2)
# y_test.shape =  (323, 1)

# %% [markdown]
# # 将 NumPy 数组转换为 Torch 张量 AFTER 分割

# %%
x_train = torch.from_numpy(x_train).type(torch.Tensor).to(args.device)
x_val = torch.from_numpy(x_val).type(torch.Tensor).to(args.device)
y_train = torch.from_numpy(y_train).type(torch.Tensor).to(args.device)
y_val = torch.from_numpy(y_val).type(torch.Tensor).to(args.device)
x_test = torch.from_numpy(x_test).type(torch.Tensor).to(args.device)
y_test = torch.from_numpy(y_test).type(torch.Tensor).to(args.device)

# %% [markdown]
# # 确保数据类型正确

# %%
assert isinstance(y_train, torch.Tensor), "y_train is not a tensor"

# %% [markdown]
# # 模型初始化

# %%
if args.model_name == 'LSTM':
    model = LSTM(input_dim=len(args.input_features), hidden_dim=args.hidden_dim, num_layers=args.n_layers, output_dim=len(args.output_features))
elif args.model_name == 'LSTM_ekan':
    model = LSTM_ekan(input_dim=len(args.input_features), hidden_dim=args.hidden_dim, num_layers=args.n_layers, output_dim=len(args.output_features))
elif args.model_name == 'BiLSTM':
    model = BiLSTM(input_dim=len(args.input_features), hidden_dim=args.hidden_dim, num_layers=args.n_layers, output_dim=len(args.output_features))
elif args.model_name == 'BiLSTM_ekan':
    model = BiLSTM_ekan(input_dim=len(args.input_features), hidden_dim=args.hidden_dim, num_layers=args.n_layers, output_dim=len(args.output_features))
elif args.model_name == 'GRUwGNN':
    model = GRUwGNN(input_dim=len(args.input_features), hidden_dim=args.hidden_dim, num_layers=args.n_layers, output_dim=len(args.output_features))
elif args.model_name == 'GRU_ekanwGNN':
    model = GRU_ekanwGNN(input_dim=len(args.input_features), hidden_dim=args.hidden_dim, num_layers=args.n_layers, output_dim=len(args.output_features))
elif args.model_name == 'LSTM_Attention':
    model = LSTM_Attention(input_dim=len(args.input_features), hidden_dim=args.hidden_dim, num_layers=args.n_layers, output_dim=len(args.output_features))
elif args.model_name == 'CustomLSTM':
    model = CustomLSTM(input_dim=len(args.input_features), hidden_dim=args.hidden_dim, num_layers=args.n_layers, output_dim=len(args.output_features))
elif args.model_name == 'GRU':
    model = GRU(input_dim=len(args.input_features), hidden_dim=args.hidden_dim, num_layers=args.n_layers, output_dim=len(args.output_features))
elif args.model_name == 'ConvLSTM':
    model = ConvLSTM(
    input_dim=19,
    hidden_dim=args.hidden_dim,
    num_layers=args.n_layers,
    output_dim=len(args.output_features),
    kernel_size=args.kernel_size
)
elif args.model_name == 'TimeGNN':
    model = TimeGNN(
        # 移除loss参数
        input_dim=len(args.input_features),
        hidden_dim=args.hidden_dim,
        output_dim=len(args.output_features),
        seq_len=args.seq_len,
        batch_size=args.batch_size,
        aggregate=args.aggregate,
        keep_self_loops=args.keep_self_loops,
        enforce_consecutive=args.enforce_consecutive,
        block_size=args.block_size
    )
elif args.model_name == 'Informer':
    model = Informer(input_dim=len(args.input_features), hidden_dim=args.hidden_dim, num_layers=args.n_layers, num_heads=args.num_heads, output_dim=len(args.output_features), dropout_rate=args.dropout)
elif args.model_name == 'ConvGRU':
    model = ConvGRU(
    input_dim=len(args.input_features),
    hidden_dim=args.hidden_dim,
    num_layers=args.n_layers,
    output_dim=len(args.output_features),
    kernel_size=args.kernel_size
)
elif args.model_name == 'VanillaLSTM':
    model = VanillaLSTM(input_dim=len(args.input_features), hidden_dim=args.hidden_dim, num_layers=args.n_layers, output_dim=len(args.output_features))
elif args.model_name == 'GRU_ekan':
    model = GRU_ekan(input_dim=len(args.input_features), hidden_dim=args.hidden_dim, num_layers=args.n_layers, output_dim=len(args.output_features))
elif args.model_name == 'TCN':
    model = TemporalConvNet(num_inputs=len(args.input_features), num_outputs=len(args.output_features), num_channels=args.num_channels, kernel_size=args.kernel_size, dropout=args.dropout)
elif args.model_name == 'TCN_ekan':
    model = TemporalConvNet_ekan(num_inputs=len(args.input_features), num_outputs=len(args.output_features), num_channels=args.num_channels, kernel_size=args.kernel_size, dropout=args.dropout)
elif args.model_name == 'Transformer':
    model = TimeSeriesTransformer(input_dim=len(args.input_features), num_heads=args.num_heads, num_layers=args.n_layers, num_outputs=len(args.output_features), hidden_space=args.hidden_space, dropout_rate=args.dropout)
elif args.model_name == 'Transformer_ekan':
    model = TimeSeriesTransformer_ekan(input_dim=len(args.input_features), num_heads=args.num_heads, num_layers=args.n_layers, num_outputs=len(args.output_features), hidden_space=args.hidden_space, dropout_rate=args.dropout)
else:
    raise ValueError('请选择正确的模型名称')
model = model.to(args.device)

# %% [markdown]
# # 损失函数和优化器

# %%
criterion = nn.MSELoss()
optimiser = torch.optim.Adam(model.parameters(), lr=args.lr)

# %% [markdown]
# # 初始化 EarlyStopping（如果启用）

# %%
if args.use_early_stopping:
    checkpoint_path = f'../{args.model_name}/best_model.pt'
    early_stopping = EarlyStopping(patience=args.patience, verbose=True, delta=args.delta, path=checkpoint_path)
    print("启用早停机制。")
else:
    early_stopping = None
    print("未启用早停机制。")
# Out:
# 启用早停机制。

# %% [markdown]
# # 初始化历史记录

# %%
train_MSE_hist = []
train_R2_hist = []
train_MAE_hist = []
val_MSE_hist = []
val_R2_hist = []
val_MAE_hist = []

output_dir_train = f'../{args.model_name}/train'
output_dir_val = f'../{args.model_name}/val'
output_dir_test = f'../{args.model_name}/test'  # 明确声明

os.makedirs(output_dir_train, exist_ok=True)
os.makedirs(output_dir_val, exist_ok=True)
os.makedirs(output_dir_test, exist_ok=True)  # 创建目录

# %% [markdown]
# # 开始训练

# %%
start_time = time.time()
result = []
for epoch in range(args.num_epochs):
    # 训练模式
    model.train()
    y_train_pred = model(x_train)
    # 计算训练损失
    train_loss = criterion(y_train_pred, y_train)
    # 反向传播和优化
    optimiser.zero_grad()
    train_loss.backward()
    optimiser.step()
    # 计算训练 R2 和 MAE
    train_r2 = r2_score(y_train.detach().cpu().numpy(), y_train_pred.detach().cpu().numpy())
    train_mae = mean_absolute_error(y_train.detach().cpu().numpy(), y_train_pred.detach().cpu().numpy())
    # 验证模式
    model.eval()
    with torch.no_grad():
        y_val_pred = model(x_val)
        val_loss = criterion(y_val_pred, y_val)
        val_r2 = r2_score(y_val.detach().cpu().numpy(), y_val_pred.detach().cpu().numpy())
        val_mae = mean_absolute_error(y_val.detach().cpu().numpy(), y_val_pred.detach().cpu().numpy())
    # 打印训练和验证信息
    print(f"Epoch {epoch+1}/{args.num_epochs} | "
          f"Train MSE: {train_loss.item():.4f} | Train MAE: {train_mae:.4f} | Train R2: {train_r2:.4f} | "
          f"Val MSE: {val_loss.item():.4f} | Val MAE: {val_mae:.4f} | Val R2: {val_r2:.4f}")
    # 记录历史
    train_MSE_hist.append(train_loss.item())
    train_R2_hist.append(train_r2)
    train_MAE_hist.append(train_mae)
    val_MSE_hist.append(val_loss.item())
    val_R2_hist.append(val_r2)
    val_MAE_hist.append(val_mae)
    # 早停检查（如果启用）
    if args.use_early_stopping:
        early_stopping(val_loss.item(), model)
        if early_stopping.early_stop:
            print("早停机制触发，停止训练。")
            break
# Out:
# Epoch 1/10000 | Train MSE: 0.1555 | Train MAE: 0.3215 | Train R2: -0.1939 | Val MSE: 0.1591 | Val MAE: 0.3198 | Val R2: -0.0646
# Validation loss decreased (inf --> 0.159126).  Saving model ...
# Epoch 2/10000 | Train MSE: 0.1515 | Train MAE: 0.3170 | Train R2: -0.1633 | Val MSE: 0.1565 | Val MAE: 0.3168 | Val R2: -0.0471
# Validation loss decreased (0.159126 --> 0.156515).  Saving model ...
# Epoch 3/10000 | Train MSE: 0.1478 | Train MAE: 0.3127 | Train R2: -0.1348 | Val MSE: 0.1542 | Val MAE: 0.3142 | Val R2: -0.0315
# Validation loss decreased (0.156515 --> 0.154186).  Saving model ...
# Epoch 4/10000 | Train MSE: 0.1444 | Train MAE: 0.3087 | Train R2: -0.1086 | Val MSE: 0.1521 | Val MAE: 0.3117 | Val R2: -0.0178
# Validation loss decreased (0.154186 --> 0.152136).  Saving model ...
# Epoch 5/10000 | Train MSE: 0.1412 | Train MAE: 0.3050 | Train R2: -0.0844 | Val MSE: 0.1504 | Val MAE: 0.3095 | Val R2: -0.0059
# Validation loss decreased (0.152136 --> 0.150365).  Saving model ...
# Epoch 6/10000 | Train MSE: 0.1384 | Train MAE: 0.3017 | Train R2: -0.0624 | Val MSE: 0.1489 | Val MAE: 0.3076 | Val R2: 0.0040
# Validation loss decreased (0.150365 --> 0.148875).  Saving model ...
# Epoch 7/10000 | Train MSE: 0.1358 | Train MAE: 0.2988 | Train R2: -0.0424 | Val MSE: 0.1477 | Val MAE: 0.3059 | Val R2: 0.0121
# Validation loss decreased (0.148875 --> 0.147674).  Saving model ...
# Epoch 8/10000 | Train MSE: 0.1334 | Train MAE: 0.2960 | Train R2: -0.0246 | Val MSE: 0.1468 | Val MAE: 0.3044 | Val R2: 0.0181
# Validation loss decreased (0.147674 --> 0.146765).  Saving model ...
# Epoch 9/10000 | Train MSE: 0.1314 | Train MAE: 0.2934 | Train R2: -0.0090 | Val MSE: 0.1462 | Val MAE: 0.3035 | Val R2: 0.0222
# Validation loss decreased (0.146765 --> 0.146155).  Saving model ...
# Epoch 10/10000 | Train MSE: 0.1297 | Train MAE: 0.2912 | Train R2: 0.0044 | Val MSE: 0.1458 | Val MAE: 0.3030 | Val R2: 0.0243
# Validation loss decreased (0.143519 --> 0.141982).  Saving model ...
# Epoch 25/10000 | Train MSE: 0.1196 | Train MAE: 0.2768 | Train R2: 0.0817 | Val MSE: 0.1404 | Val MAE: 0.2963 | Val R2: 0.0605
# Validation loss decreased (0.141982 --> 0.140436).  Saving model ...
# Epoch 26/10000 | Train MSE: 0.1187 | Train MAE: 0.2759 | Train R2: 0.0889 | Val MSE: 0.1389 | Val MAE: 0.2947 | Val R2: 0.0706
# Validation loss decreased (0.140436 --> 0.138919).  Saving model ...
# Epoch 27/10000 | Train MSE: 0.1178 | Train MAE: 0.2750 | Train R2: 0.0958 | Val MSE: 0.1375 | Val MAE: 0.2930 | Val R2: 0.0804
# Validation loss decreased (0.138919 --> 0.137452).  Saving model ...
# Epoch 28/10000 | Train MSE: 0.1169 | Train MAE: 0.2741 | Train R2: 0.1025 | Val MSE: 0.1360 | Val MAE: 0.2914 | Val R2: 0.0899
# Validation loss decreased (0.137452 --> 0.136040).  Saving model ...
# Epoch 29/10000 | Train MSE: 0.1160 | Train MAE: 0.2731 | Train R2: 0.1089 | Val MSE: 0.1347 | Val MAE: 0.2897 | Val R2: 0.0990
# Validation loss decreased (0.136040 --> 0.134678).  Saving model ...
# Epoch 30/10000 | Train MSE: 0.1152 | Train MAE: 0.2721 | Train R2: 0.1154 | Val MSE: 0.1334 | Val MAE: 0.2882 | Val R2: 0.1078
# Validation loss decreased (0.134678 --> 0.133356).  Saving model ...
# Epoch 31/10000 | Train MSE: 0.1143 | Train MAE: 0.2711 | Train R2: 0.1221 | Val MSE: 0.1321 | Val MAE: 0.2867 | Val R2: 0.1165
# Validation loss decreased (0.133356 --> 0.132065).  Saving model ...
# Epoch 32/10000 | Train MSE: 0.1134 | Train MAE: 0.2699 | Train R2: 0.1290 | Val MSE: 0.1308 | Val MAE: 0.2851 | Val R2: 0.1250
# Validation loss decreased (0.132065 --> 0.130798).  Saving model ...
# Epoch 33/10000 | Train MSE: 0.1125 | Train MAE: 0.2686 | Train R2: 0.1365 | Val MSE: 0.1296 | Val MAE: 0.2837 | Val R2: 0.1332
# Validation loss decreased (0.130798 --> 0.129560).  Saving model ...
# Epoch 34/10000 | Train MSE: 0.1114 | Train MAE: 0.2672 | Train R2: 0.1444 | Val MSE: 0.1284 | Val MAE: 0.2823 | Val R2: 0.1412
# Validation loss decreased (0.129560 --> 0.128367).  Saving model ...
# Epoch 35/10000 | Train MSE: 0.1103 | Train MAE: 0.2657 | Train R2: 0.1528 | Val MSE: 0.1273 | Val MAE: 0.2809 | Val R2: 0.1486
# Validation loss decreased (0.128367 --> 0.127258).  Saving model ...
# Epoch 36/10000 | Train MSE: 0.1092 | Train MAE: 0.2640 | Train R2: 0.1614 | Val MSE: 0.1263 | Val MAE: 0.2797 | Val R2: 0.1551
# Validation loss decreased (0.127258 --> 0.126297).  Saving model ...
# Epoch 37/10000 | Train MSE: 0.1081 | Train MAE: 0.2622 | Train R2: 0.1696 | Val MSE: 0.1256 | Val MAE: 0.2792 | Val R2: 0.1599
# Validation loss decreased (0.126297 --> 0.125570).  Saving model ...
# Epoch 38/10000 | Train MSE: 0.1072 | Train MAE: 0.2606 | Train R2: 0.1768 | Val MSE: 0.1252 | Val MAE: 0.2792 | Val R2: 0.1627
# Validation loss decreased (0.125570 --> 0.125157).  Saving model ...
# Epoch 39/10000 | Train MSE: 0.1065 | Train MAE: 0.2591 | Train R2: 0.1821 | Val MSE: 0.1250 | Val MAE: 0.2795 | Val R2: 0.1635
# Validation loss decreased (0.125157 --> 0.125045).  Saving model ...
# Epoch 40/10000 | Train MSE: 0.1061 | Train MAE: 0.2580 | Train R2: 0.1849 | Val MSE: 0.1250 | Val MAE: 0.2795 | Val R2: 0.1639
# Validation loss decreased (0.125045 --> 0.124973).  Saving model ...
# Epoch 41/10000 | Train MSE: 0.1060 | Train MAE: 0.2574 | Train R2: 0.1858 | Val MSE: 0.1245 | Val MAE: 0.2786 | Val R2: 0.1673
# Validation loss decreased (0.124973 --> 0.124464).  Saving model ...
# Epoch 42/10000 | Train MSE: 0.1059 | Train MAE: 0.2571 | Train R2: 0.1868 | Val MSE: 0.1233 | Val MAE: 0.2772 | Val R2: 0.1751
# Validation loss decreased (0.124464 --> 0.123301).  Saving model ...
# Epoch 43/10000 | Train MSE: 0.1056 | Train MAE: 0.2569 | Train R2: 0.1892 | Val MSE: 0.1218 | Val MAE: 0.2758 | Val R2: 0.1854
# Validation loss decreased (0.123301 --> 0.121763).  Saving model ...
# Epoch 44/10000 | Train MSE: 0.1053 | Train MAE: 0.2569 | Train R2: 0.1917 | Val MSE: 0.1203 | Val MAE: 0.2746 | Val R2: 0.1951
# Validation loss decreased (0.121763 --> 0.120307).  Saving model ...
# Epoch 45/10000 | Train MSE: 0.1052 | Train MAE: 0.2574 | Train R2: 0.1926 | Val MSE: 0.1192 | Val MAE: 0.2738 | Val R2: 0.2024
# Validation loss decreased (0.120307 --> 0.119230).  Saving model ...
# Epoch 46/10000 | Train MSE: 0.1053 | Train MAE: 0.2582 | Train R2: 0.1914 | Val MSE: 0.1186 | Val MAE: 0.2732 | Val R2: 0.2068
# Validation loss decreased (0.119230 --> 0.118561).  Saving model ...
# Epoch 47/10000 | Train MSE: 0.1056 | Train MAE: 0.2590 | Train R2: 0.1893 | Val MSE: 0.1182 | Val MAE: 0.2729 | Val R2: 0.2094
# Validation loss decreased (0.118561 --> 0.118178).  Saving model ...
# Epoch 48/10000 | Train MSE: 0.1058 | Train MAE: 0.2595 | Train R2: 0.1879 | Val MSE: 0.1180 | Val MAE: 0.2727 | Val R2: 0.2108
# Validation loss decreased (0.118178 --> 0.117973).  Saving model ...
# Epoch 49/10000 | Train MSE: 0.1057 | Train MAE: 0.2595 | Train R2: 0.1880 | Val MSE: 0.1179 | Val MAE: 0.2725 | Val R2: 0.2112
# Validation loss decreased (0.117973 --> 0.117909).  Saving model ...
# EarlyStopping counter: 15 out of 250
# Epoch 65/10000 | Train MSE: 0.1038 | Train MAE: 0.2561 | Train R2: 0.2030 | Val MSE: 0.1185 | Val MAE: 0.2693 | Val R2: 0.2073
# EarlyStopping counter: 16 out of 250
# Epoch 66/10000 | Train MSE: 0.1037 | Train MAE: 0.2560 | Train R2: 0.2035 | Val MSE: 0.1184 | Val MAE: 0.2692 | Val R2: 0.2077
# EarlyStopping counter: 17 out of 250
# Epoch 67/10000 | Train MSE: 0.1037 | Train MAE: 0.2558 | Train R2: 0.2041 | Val MSE: 0.1184 | Val MAE: 0.2692 | Val R2: 0.2082
# EarlyStopping counter: 18 out of 250
# Epoch 68/10000 | Train MSE: 0.1036 | Train MAE: 0.2557 | Train R2: 0.2047 | Val MSE: 0.1183 | Val MAE: 0.2691 | Val R2: 0.2089
# EarlyStopping counter: 19 out of 250
# Epoch 69/10000 | Train MSE: 0.1035 | Train MAE: 0.2555 | Train R2: 0.2053 | Val MSE: 0.1181 | Val MAE: 0.2690 | Val R2: 0.2097
# EarlyStopping counter: 20 out of 250
# Epoch 70/10000 | Train MSE: 0.1034 | Train MAE: 0.2553 | Train R2: 0.2059 | Val MSE: 0.1180 | Val MAE: 0.2688 | Val R2: 0.2109
# EarlyStopping counter: 21 out of 250
# Epoch 71/10000 | Train MSE: 0.1034 | Train MAE: 0.2552 | Train R2: 0.2064 | Val MSE: 0.1177 | Val MAE: 0.2685 | Val R2: 0.2123
# Validation loss decreased (0.117909 --> 0.117738).  Saving model ...
# Epoch 72/10000 | Train MSE: 0.1033 | Train MAE: 0.2551 | Train R2: 0.2069 | Val MSE: 0.1175 | Val MAE: 0.2681 | Val R2: 0.2141
# Validation loss decreased (0.117738 --> 0.117472).  Saving model ...
# Epoch 73/10000 | Train MSE: 0.1032 | Train MAE: 0.2550 | Train R2: 0.2073 | Val MSE: 0.1172 | Val MAE: 0.2677 | Val R2: 0.2161
# Validation loss decreased (0.117472 --> 0.117171).  Saving model ...
# Epoch 74/10000 | Train MSE: 0.1032 | Train MAE: 0.2549 | Train R2: 0.2077 | Val MSE: 0.1169 | Val MAE: 0.2672 | Val R2: 0.2183
# Validation loss decreased (0.117171 --> 0.116852).  Saving model ...
# Epoch 75/10000 | Train MSE: 0.1031 | Train MAE: 0.2549 | Train R2: 0.2080 | Val MSE: 0.1165 | Val MAE: 0.2669 | Val R2: 0.2204
# Validation loss decreased (0.116852 --> 0.116539).  Saving model ...
# Epoch 76/10000 | Train MSE: 0.1031 | Train MAE: 0.2549 | Train R2: 0.2083 | Val MSE: 0.1163 | Val MAE: 0.2666 | Val R2: 0.2223
# Validation loss decreased (0.116539 --> 0.116255).  Saving model ...
# Epoch 77/10000 | Train MSE: 0.1031 | Train MAE: 0.2550 | Train R2: 0.2085 | Val MSE: 0.1160 | Val MAE: 0.2663 | Val R2: 0.2238
# Validation loss decreased (0.116255 --> 0.116019).  Saving model ...
# Epoch 119/10000 | Train MSE: 0.1011 | Train MAE: 0.2522 | Train R2: 0.2238 | Val MSE: 0.1154 | Val MAE: 0.2652 | Val R2: 0.2280
# Validation loss decreased (0.115448 --> 0.115390).  Saving model ...
# Epoch 120/10000 | Train MSE: 0.1010 | Train MAE: 0.2521 | Train R2: 0.2243 | Val MSE: 0.1153 | Val MAE: 0.2651 | Val R2: 0.2284
# Validation loss decreased (0.115390 --> 0.115330).  Saving model ...
# Epoch 121/10000 | Train MSE: 0.1009 | Train MAE: 0.2520 | Train R2: 0.2249 | Val MSE: 0.1153 | Val MAE: 0.2650 | Val R2: 0.2288
# Validation loss decreased (0.115330 --> 0.115271).  Saving model ...
# Epoch 122/10000 | Train MSE: 0.1009 | Train MAE: 0.2519 | Train R2: 0.2255 | Val MSE: 0.1152 | Val MAE: 0.2650 | Val R2: 0.2292
# Validation loss decreased (0.115271 --> 0.115219).  Saving model ...
# Epoch 123/10000 | Train MSE: 0.1008 | Train MAE: 0.2517 | Train R2: 0.2261 | Val MSE: 0.1152 | Val MAE: 0.2649 | Val R2: 0.2295
# Validation loss decreased (0.115219 --> 0.115177).  Saving model ...
# Epoch 124/10000 | Train MSE: 0.1007 | Train MAE: 0.2516 | Train R2: 0.2267 | Val MSE: 0.1151 | Val MAE: 0.2649 | Val R2: 0.2297
# Validation loss decreased (0.115177 --> 0.115146).  Saving model ...
# Epoch 125/10000 | Train MSE: 0.1006 | Train MAE: 0.2515 | Train R2: 0.2273 | Val MSE: 0.1151 | Val MAE: 0.2649 | Val R2: 0.2298
# Validation loss decreased (0.115146 --> 0.115125).  Saving model ...
# Epoch 126/10000 | Train MSE: 0.1005 | Train MAE: 0.2514 | Train R2: 0.2280 | Val MSE: 0.1151 | Val MAE: 0.2649 | Val R2: 0.2299
# Validation loss decreased (0.115125 --> 0.115111).  Saving model ...
# Epoch 127/10000 | Train MSE: 0.1005 | Train MAE: 0.2513 | Train R2: 0.2286 | Val MSE: 0.1151 | Val MAE: 0.2649 | Val R2: 0.2300
# Validation loss decreased (0.115111 --> 0.115101).  Saving model ...
# Epoch 128/10000 | Train MSE: 0.1004 | Train MAE: 0.2511 | Train R2: 0.2293 | Val MSE: 0.1151 | Val MAE: 0.2649 | Val R2: 0.2301
# Validation loss decreased (0.115101 --> 0.115088).  Saving model ...
# Epoch 129/10000 | Train MSE: 0.1003 | Train MAE: 0.2510 | Train R2: 0.2301 | Val MSE: 0.1151 | Val MAE: 0.2649 | Val R2: 0.2302
# Validation loss decreased (0.115088 --> 0.115070).  Saving model ...
# Epoch 130/10000 | Train MSE: 0.1002 | Train MAE: 0.2509 | Train R2: 0.2308 | Val MSE: 0.1150 | Val MAE: 0.2649 | Val R2: 0.2304
# Validation loss decreased (0.115070 --> 0.115042).  Saving model ...
# Epoch 131/10000 | Train MSE: 0.1001 | Train MAE: 0.2507 | Train R2: 0.2316 | Val MSE: 0.1150 | Val MAE: 0.2648 | Val R2: 0.2306
# Validation loss decreased (0.115042 --> 0.115002).  Saving model ...
# Epoch 145/10000 | Train MSE: 0.0982 | Train MAE: 0.2481 | Train R2: 0.2458 | Val MSE: 0.1139 | Val MAE: 0.2635 | Val R2: 0.2378
# Validation loss decreased (0.114038 --> 0.113928).  Saving model ...
# Epoch 146/10000 | Train MSE: 0.0980 | Train MAE: 0.2478 | Train R2: 0.2471 | Val MSE: 0.1138 | Val MAE: 0.2633 | Val R2: 0.2386
# Validation loss decreased (0.113928 --> 0.113812).  Saving model ...
# Epoch 147/10000 | Train MSE: 0.0979 | Train MAE: 0.2475 | Train R2: 0.2485 | Val MSE: 0.1137 | Val MAE: 0.2632 | Val R2: 0.2394
# Validation loss decreased (0.113812 --> 0.113690).  Saving model ...
# Epoch 148/10000 | Train MSE: 0.0977 | Train MAE: 0.2472 | Train R2: 0.2500 | Val MSE: 0.1136 | Val MAE: 0.2630 | Val R2: 0.2403
# Validation loss decreased (0.113690 --> 0.113560).  Saving model ...
# Epoch 149/10000 | Train MSE: 0.0975 | Train MAE: 0.2469 | Train R2: 0.2515 | Val MSE: 0.1134 | Val MAE: 0.2628 | Val R2: 0.2412
# Validation loss decreased (0.113560 --> 0.113420).  Saving model ...
# Epoch 150/10000 | Train MSE: 0.0973 | Train MAE: 0.2466 | Train R2: 0.2531 | Val MSE: 0.1133 | Val MAE: 0.2625 | Val R2: 0.2423
# Validation loss decreased (0.113420 --> 0.113266).  Saving model ...
# Epoch 151/10000 | Train MSE: 0.0971 | Train MAE: 0.2462 | Train R2: 0.2547 | Val MSE: 0.1131 | Val MAE: 0.2622 | Val R2: 0.2434
# Validation loss decreased (0.113266 --> 0.113095).  Saving model ...
# Epoch 152/10000 | Train MSE: 0.0968 | Train MAE: 0.2458 | Train R2: 0.2564 | Val MSE: 0.1129 | Val MAE: 0.2619 | Val R2: 0.2447
# Validation loss decreased (0.113095 --> 0.112903).  Saving model ...
# Epoch 153/10000 | Train MSE: 0.0966 | Train MAE: 0.2454 | Train R2: 0.2582 | Val MSE: 0.1127 | Val MAE: 0.2615 | Val R2: 0.2461
# Validation loss decreased (0.112903 --> 0.112692).  Saving model ...
# Epoch 154/10000 | Train MSE: 0.0964 | Train MAE: 0.2450 | Train R2: 0.2600 | Val MSE: 0.1125 | Val MAE: 0.2611 | Val R2: 0.2476
# Validation loss decreased (0.112692 --> 0.112462).  Saving model ...
# Epoch 155/10000 | Train MSE: 0.0961 | Train MAE: 0.2446 | Train R2: 0.2619 | Val MSE: 0.1122 | Val MAE: 0.2606 | Val R2: 0.2493
# Validation loss decreased (0.112462 --> 0.112213).  Saving model ...
# Epoch 156/10000 | Train MSE: 0.0959 | Train MAE: 0.2441 | Train R2: 0.2639 | Val MSE: 0.1119 | Val MAE: 0.2601 | Val R2: 0.2511
# Validation loss decreased (0.112213 --> 0.111948).  Saving model ...
# Epoch 157/10000 | Train MSE: 0.0956 | Train MAE: 0.2436 | Train R2: 0.2659 | Val MSE: 0.1117 | Val MAE: 0.2595 | Val R2: 0.2530
# Validation loss decreased (0.111948 --> 0.111664).  Saving model ...
# EarlyStopping counter: 249 out of 250
# Epoch 455/10000 | Train MSE: 0.0824 | Train MAE: 0.2234 | Train R2: 0.3675 | Val MSE: 0.1020 | Val MAE: 0.2411 | Val R2: 0.3174
# EarlyStopping counter: 250 out of 250
# 早停机制触发，停止训练。

# %% [markdown]
# # 记录训练时间

# %%
training_time = time.time() - start_time
print("训练时间: {:.5f} 秒".format(training_time))
# Out:
# 训练时间: 68.69043 秒

# %%
# Custom interval prediction logic
if args.predict_start is not None or args.predict_end is not None:
    # Check if both start and end indices are provided
    if args.predict_start is None or args.predict_end is None:
        raise ValueError("Both --predict_start and --predict_end parameters must be provided")
    
    # Validate index validity
    if args.predict_start < args.window_size:
        raise ValueError(f"predict_start must be greater than or equal to the window size {args.window_size}")
    if args.predict_end >= len(features_scaled):
        raise ValueError(f"predict_end must be less than the data length {len(features_scaled)}")
    if args.predict_start > args.predict_end:
        raise ValueError("predict_start must be less than or equal to predict_end")

    # Generate input window data
    x_custom = []
    for i in range(args.predict_start, args.predict_end + 1):
        start_idx = i - args.window_size
        end_idx = i
        window_data = features_scaled[start_idx:end_idx, :]  # (window_size, n_features)
        x_custom.append(window_data)
    x_custom = np.array(x_custom)  # (n_samples, window_size, n_features)
    
    # Convert to tensor
    x_custom_tensor = torch.from_numpy(x_custom).float().to(args.device)
    
    # Perform prediction
    model.eval()
    with torch.no_grad():
        y_custom_pred = model(x_custom_tensor)
    
    # Inverse transform prediction results
    y_custom_pred_inv = target_scaler.inverse_transform(y_custom_pred.cpu().numpy())
    
    # Get true values
    y_custom_true = target_scaler.inverse_transform(target_scaled[args.predict_start:args.predict_end + 1])
    
    # Evaluation metrics
    custom_rmse = math.sqrt(mean_squared_error(y_custom_true, y_custom_pred_inv))
    custom_mae = mean_absolute_error(y_custom_true, y_custom_pred_inv)
    custom_r2 = r2_score(y_custom_true, y_custom_pred_inv)
    
    print(f"\nCustom Prediction Results ({args.predict_start}-{args.predict_end}):")
    print(f"RMSE: {custom_rmse:.5f}")
    print(f"MAE: {custom_mae:.5f}")
    print(f"R²: {custom_r2:.5f}")

    # Visualize results
    output_dir_custom = f'../{args.model_name}/custom'
    os.makedirs(output_dir_custom, exist_ok=True)
    
    for i in range(len(args.output_features)):
        feature_name = param_index_dict[i]
        plt.figure(figsize=(14, 6))
        
        # Generate x-axis labels
        if 'DATE' in data.columns:
            dates = data['DATE'].iloc[args.predict_start:args.predict_end + 1]
            x_axis = dates
        else:
            x_axis = range(args.predict_start, args.predict_end + 1)
        
        plt.plot(x_axis, y_custom_true[:, i], label='Actual Value', color='blue')
        plt.plot(x_axis, y_custom_pred_inv[:, i], label='Predicted Value', color='red', linestyle='--')
        
        plt.title(f'{feature_name} Prediction Comparison (Index {args.predict_start}-{args.predict_end})')
        plt.xlabel('Date' if 'DATE' in data.columns else 'Index')
        plt.ylabel('Value')
        plt.legend()
        plt.grid(True)
        
        # Save the plot
        timestamp = time.strftime("%Y%m%d_%H%M%S")
        plt.savefig(os.path.join(output_dir_custom, 
                    f'custom_{feature_name}_{args.predict_start}_to_{args.predict_end}_{timestamp}.png'))
        plt.close()

# Load the best model (if early stopping is enabled)
if args.use_early_stopping:
    model.load_state_dict(torch.load(checkpoint_path))

# Inverse transform prediction and true values
y_train_pred_inv = target_scaler.inverse_transform(y_train_pred.detach().cpu().numpy())
y_train_true = target_scaler.inverse_transform(y_train.detach().cpu().numpy())
y_val_pred_inv = target_scaler.inverse_transform(y_val_pred.detach().cpu().numpy())
y_val_true = target_scaler.inverse_transform(y_val.detach().cpu().numpy())
y_test_pred = model(x_test)
y_test_pred_inv = target_scaler.inverse_transform(y_test_pred.detach().cpu().numpy())
y_test_full = target_scaler.inverse_transform(y_test.detach().cpu().numpy())

# Training set evaluation
train_rmse = math.sqrt(mean_squared_error(y_train_true, y_train_pred_inv))
train_mae = mean_absolute_error(y_train_true, y_train_pred_inv)
train_mse = mean_squared_error(y_train_true, y_train_pred_inv)
r2_train = r2_score(y_train_true, y_train_pred_inv)
print('Train Score: {:.5f} RMSE'.format(train_rmse))
print('Train MAE: {:.5f}'.format(train_mae))
print('Train MSE: {:.5f}'.format(train_mse))
print('Train R^2: {:.5f}'.format(r2_train))

# Validation set evaluation
val_rmse = math.sqrt(mean_squared_error(y_val_true, y_val_pred_inv))
val_mae = mean_absolute_error(y_val_true, y_val_pred_inv)
val_mse = mean_squared_error(y_val_true, y_val_pred_inv)
r2_val = r2_score(y_val_true, y_val_pred_inv)
print('Validation Score: {:.5f} RMSE'.format(val_rmse))
print('Validation MAE: {:.5f}'.format(val_mae))
print('Validation MSE: {:.5f}'.format(val_mse))
print('Validation R^2: {:.5f}'.format(r2_val))

# Test set evaluation
test_rmse = math.sqrt(mean_squared_error(y_test_full, y_test_pred_inv))
test_mae = mean_absolute_error(y_test_full, y_test_pred_inv)
test_mse = mean_squared_error(y_test_full, y_test_pred_inv)
r2_test = r2_score(y_test_full, y_test_pred_inv)
print('Test Score: {:.5f} RMSE'.format(test_rmse))
print('Test MAE: {:.5f}'.format(test_mae))
print('Test MSE: {:.5f}'.format(test_mse))
print('Test R^2: {:.5f}'.format(r2_test))

# Save model evaluation results
file_path = 'model_scores.csv'
# Create a DataFrame containing the current model results
data_scores = {
    "Model Name": [args.model_name],
    "Train RMSE": [train_rmse],
    "Train MAE": [train_mae],
    "Train MSE": [train_mse],
    "Train R^2": [r2_train],
    "Validation RMSE": [val_rmse],
    "Validation MAE": [val_mae],
    "Validation MSE": [val_mse],
    "Validation R^2": [r2_val],
    "Test RMSE": [test_rmse],
    "Test MAE": [test_mae],
    "Test MSE": [test_mse],
    "Test R^2": [r2_test],
    "Training Time (s)": [training_time],
    # Record hyperparameters
    "Learning Rate": [args.lr],
    "Hidden Dim": [args.hidden_dim],
    "Num Layers": [args.n_layers],
    "Dropout": [args.dropout],
    "Window Size": [args.window_size],
    "Patience": [args.patience],
    "Delta": [args.delta]
}
# Ensure each run's record is unique by adding a timestamp to the model name
current_time_str_filename = time.strftime("%Y%m%d_%H%M%S", time.localtime())
df_scores = pd.DataFrame(data_scores, index=[f"{args.model_name}_{current_time_str_filename}"])
# Check if the file exists
if Path(file_path).exists():
    # File exists, append data
    df_scores.to_csv(file_path, mode='a', header=False, index=True)
else:
    # File does not exist, create the file and write data
    df_scores.to_csv(file_path, index=True)

# Inverse transform predictions for visualization
y_test_pred_full = y_test_pred_inv
y_test_full = y_test_full  # Already inverse transformed

# Create output directories
output_dir_train = f'../{args.model_name}/train'
output_dir_val = f'../{args.model_name}/val'
output_dir_test = f'../{args.model_name}/test'
os.makedirs(output_dir_train, exist_ok=True)
os.makedirs(output_dir_val, exist_ok=True)
os.makedirs(output_dir_test, exist_ok=True)

# Get the date or sample index from the original data
if 'DATE' in data.columns:
    dates = pd.to_datetime(data['DATE'])
    x_axis = dates
else:
    x_axis = range(len(data))

# Plot predictions for training, validation, and test sets
for i in range(len(args.output_features)):
    feature_name = param_index_dict[i]
    
    # Get the current time string
    current_time_str_filename = time.strftime("%Y%m%d_%H%M%S", time.localtime())
    
    # Plot training set prediction results
    plt.figure(figsize=(14, 6))
    plt.plot(x_axis[args.window_size:args.window_size + len(y_train_true)], y_train_true[:, i], label='Actual Train', color='blue')
    plt.plot(x_axis[args.window_size:args.window_size + len(y_train_pred_inv)], y_train_pred_inv[:, i], label=f'Train Prediction ({args.model_name})', color='orange')
    plt.title(f'Training Set Prediction vs Actual ({feature_name})', fontsize=16, fontweight='bold')
    plt.xlabel('Date' if 'DATE' in data.columns else 'Index', fontsize=14)
    plt.ylabel('Value', fontsize=14)
    plt.legend()
    plt.grid(True)
    
    # Add timestamp to filename
    plt.savefig(os.path.join(output_dir_train, f'{feature_name}_train_{current_time_str_filename}.png'))
    plt.close()
    
    # Plot validation set prediction results
    plt.figure(figsize=(14, 6))
    plt.plot(x_axis[args.window_size + len(y_train_true):args.window_size + len(y_train_true) + len(y_val_true)], y_val_true[:, i], label='Actual Validation', color='green')
    plt.plot(x_axis[args.window_size + len(y_train_true):args.window_size + len(y_train_true) + len(y_val_pred_inv)], y_val_pred_inv[:, i], label=f'Validation Prediction ({args.model_name})', color='red')
    plt.title(f'Validation Set Prediction vs Actual ({feature_name})', fontsize=16, fontweight='bold')
    plt.xlabel('Date' if 'DATE' in data.columns else 'Index', fontsize=14)
    plt.ylabel('Value', fontsize=14)
    plt.legend()
    plt.grid(True)
    
    # Add timestamp to filename
    plt.savefig(os.path.join(output_dir_val, f'{feature_name}_val_{current_time_str_filename}.png'))
    plt.close()
    
    # Plot test set prediction results
    plt.figure(figsize=(14, 6))
    plt.plot(x_axis[args.window_size + len(y_train_true) + len(y_val_true):args.window_size + len(y_train_true) + len(y_val_true) + len(y_test_full)], y_test_full[:, i], label='Actual Test', color='purple')
    plt.plot(x_axis[args.window_size + len(y_train_true) + len(y_val_true):args.window_size + len(y_train_true) + len(y_val_true) + len(y_test_pred_inv)], y_test_pred_inv[:, i], label=f'Test Prediction ({args.model_name})', color='brown')
    plt.title(f'Test Set Prediction vs Actual ', fontsize=16, fontweight='bold')
    plt.xlabel('Date' if 'DATE' in data.columns else 'Index', fontsize=14)
    plt.ylabel('Value', fontsize=14)
    plt.legend()
    plt.grid(True)
    
    # Add timestamp to filename
    plt.savefig(os.path.join(output_dir_test, f'{feature_name}_test_{current_time_str_filename}.png'))
    plt.close()

print("All prediction result plots have been completed and saved.")
# Out:
# Custom Prediction Results (400-1655):
# RMSE: 106.56980
# MAE: 80.64812
# R²: 0.21208
# Train Score: 96.86355 RMSE
# Train MAE: 75.39198
# Train MSE: 9382.54688
# Train R^2: 0.36753
# Validation Score: 107.80683 RMSE
# Validation MAE: 81.37414
# Validation MSE: 11622.31152
# Validation R^2: 0.31739
# Test Score: 90.30281 RMSE
# Test MAE: 68.34946
# Test MSE: 8154.59766
# Test R^2: 0.11804
# All prediction result plots have been completed and saved.

# %%
# output_dir = Path(f'../{args.model_name}')
# output_dir.mkdir(parents=True, exist_ok=True)# 在训练循环之后添加结果保存部分
# current_time_str = time.strftime("%Y%m%d_%H%M%S")

# # 保存训练集预测结果
# train_results = pd.DataFrame({
#     'timestamp': data['time'].iloc[args.window_size : args.window_size + len(y_train)],
#     'actual': y_train_true.squeeze(),
#     'predicted': y_train_pred_inv.squeeze()
# })
# train_results.to_csv(output_dir / f'train_results_{current_time_str}.csv', index=False)

# # 保存验证集预测结果
# val_results = pd.DataFrame({
#     'timestamp': data['time'].iloc[args.window_size + len(y_train) : args.window_size + len(y_train) + len(y_val)],
#     'actual': y_val_true.squeeze(),
#     'predicted': y_val_pred_inv.squeeze()
# })
# val_results.to_csv(output_dir / f'val_results_{current_time_str}.csv', index=False)

# # 保存测试集预测结果
# test_results = pd.DataFrame({
#     'timestamp': data['time'].iloc[args.window_size + len(y_train) + len(y_val) : args.window_size + len(y_train) + len(y_val) + len(y_test)],
#     'actual': y_test_full.squeeze(),
#     'predicted': y_test_pred_inv.squeeze()
# })
# test_results.to_csv(output_dir / f'test_results_{current_time_str}.csv', index=False)

# # 保存自定义区间预测结果（如果有）
# if 'y_custom_pred_inv' in locals():
#     custom_results = pd.DataFrame({
#         'timestamp': data['time'].iloc[args.predict_start : args.predict_end + 1],
#         'actual': y_custom_true.squeeze(),
#         'predicted': y_custom_pred_inv.squeeze()
#     })
#     custom_results.to_csv(output_dir / f'custom_{args.predict_start}-{args.predict_end}_results_{current_time_str}.csv', index=False)

# # 保存评估指标
# metrics = pd.DataFrame({
#     'dataset': ['train', 'val', 'test'],
#     'RMSE': [train_rmse, val_rmse, test_rmse],
#     'MAE': [train_mae, val_mae, test_mae],
#     'R2': [r2_train, r2_val, r2_test],
#     'MSE': [train_mse, val_mse, test_mse]
# })
# metrics.to_csv(output_dir / f'metrics_{current_time_str}.csv', index=False)

# # 保存完整配置
# with open(output_dir / f'config_{current_time_str}.txt', 'w') as f:
#     for key, value in vars(args).items():
#         f.write(f"{key}: {value}\n")

# print("所有预测结果和评估指标已保存至:", output_dir)
